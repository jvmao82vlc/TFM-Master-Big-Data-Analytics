# %%
#Imports
# -*- coding: utf-8 -*-

import pandas as pd
from IPython.display import display
import csv
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import time
import re
import plotly.express as px

from numpy import mean
from numpy import absolute
from numpy import sqrt

import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.dummy import DummyRegressor
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, cross_val_predict

from sklearn.linear_model import LinearRegression,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasClassifier

from sklearn.preprocessing import StandardScaler,LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer, ColumnTransformer

# %%
#Cargamos dataset
dataML_split = pd.read_csv('/../TFM/csv_bigdata/datos_filtrados.csv',sep=';',engine='python')

# %%
#Cambiamos columna fecha a datetime
dataML_split['fecha']= pd.to_datetime(dataML_split['fecha'],format='%Y-%m-%d')

# %%
dataML_split.dtypes
# Out:
# fecha         datetime64[ns]
# dia_semana            object
# hora                  object
# id_tramo              object
# des_tramo             object
# estado                 int64
# longitud             float64
# latitud              float64
# dtype: object

# %%
dataML_split.head(5)
# Out:
#        fecha dia_semana      hora id_tramo               des_tramo  estado  \
# 0 2015-01-01     Jueves  00:15:01     A102          ERNESTO FERRER      37
# 1 2015-01-01     Jueves  00:15:01     A104           EUGENIA VIÑES      33
# 2 2015-01-01     Jueves  00:15:01     A124       GUILLEM DE CASTRO     139
# 3 2015-01-01     Jueves  00:15:01     A127       GUILLEM DE CASTRO     187
# 4 2015-01-01     Jueves  00:15:01     A122  GRAN VIA RAMON Y CAJAL     218
#
#    longitud    latitud
# 0 -0.354378  39.471478
# 1 -0.325181  39.467414
# 2 -0.383419  39.470396
# 3 -0.384150  39.475677
# 4 -0.335824  39.460994

# %%
dataML_split.tail(5)
# Out:
#               fecha dia_semana      hora id_tramo            des_tramo  \
# 11899954 2015-12-31     Jueves  23:00:02      B86      POETA MAS Y ROS
# 11899955 2015-12-31     Jueves  23:00:02      B87       POETA MONMENEU
# 11899956 2015-12-31     Jueves  23:00:02      B95  RODRÍGUEZ DE CEPEDA
# 11899957 2015-12-31     Jueves  23:00:02      B97              SAGASTA
# 11899958 2015-12-31     Jueves  23:00:02      B98         SANTA AMALIA
#
#           estado  longitud    latitud
# 11899954      12 -0.350830  39.471145
# 11899955      21 -0.374962  39.482774
# 11899956      47 -0.352085  39.468331
# 11899957      44 -0.373892  39.469853
# 11899958      38 -0.372333  39.481233

# %%
#Dividimos las columnas temporales en year,month,day,hours,minutes,seconds
dataML_split['año'] = dataML_split['fecha'].dt.year
dataML_split['mes'] = dataML_split['fecha'].dt.month
dataML_split['dia'] = dataML_split['fecha'].dt.day
dataML_split['horas'] = pd.to_datetime(dataML_split['hora']).dt.hour
dataML_split['minutos'] = pd.to_datetime(dataML_split['hora']).dt.minute
dataML_split['segundos'] = pd.to_datetime(dataML_split['hora']).dt.second

dataML_split.head(5)
# Out:
#        fecha dia_semana      hora id_tramo               des_tramo  estado  \
# 0 2015-01-01     Jueves  00:15:01     A102          ERNESTO FERRER      37
# 1 2015-01-01     Jueves  00:15:01     A104           EUGENIA VIÑES      33
# 2 2015-01-01     Jueves  00:15:01     A124       GUILLEM DE CASTRO     139
# 3 2015-01-01     Jueves  00:15:01     A127       GUILLEM DE CASTRO     187
# 4 2015-01-01     Jueves  00:15:01     A122  GRAN VIA RAMON Y CAJAL     218
#
#    longitud    latitud   año  mes  dia  horas  minutos  segundos
# 0 -0.354378  39.471478  2015    1    1      0       15         1
# 1 -0.325181  39.467414  2015    1    1      0       15         1
# 2 -0.383419  39.470396  2015    1    1      0       15         1
# 3 -0.384150  39.475677  2015    1    1      0       15         1
# 4 -0.335824  39.460994  2015    1    1      0       15         1

# %%
dataML_split[['fecha','año','mes','dia','hora','horas','minutos','segundos']].head(5)
# Out:
#        fecha   año  mes  dia      hora  horas  minutos  segundos
# 0 2015-01-01  2015    1    1  00:15:01      0       15         1
# 1 2015-01-01  2015    1    1  00:15:01      0       15         1
# 2 2015-01-01  2015    1    1  00:15:01      0       15         1
# 3 2015-01-01  2015    1    1  00:15:01      0       15         1
# 4 2015-01-01  2015    1    1  00:15:01      0       15         1

# %%
#Convertimos la columna dia_semana a categórica
conditions_days = [(dataML_split['dia_semana'] == 'Lunes'),
                  (dataML_split['dia_semana'] == 'Martes'),
                  (dataML_split['dia_semana'] == 'Miércoles'),
                  (dataML_split['dia_semana'] == 'Jueves'),
                  (dataML_split['dia_semana'] == 'Viernes'),
                  (dataML_split['dia_semana'] == 'Sábado'),
                  (dataML_split['dia_semana'] == 'Domingo')]

values_days = [1,2,3,4,5,6,7]

#dataML_split['dias'] = np.select(conditions_days,values_days)
dataML_split['dias_sem'] = np.select(conditions_days,values_days)
dataML_split['dias_sem'].values.astype(np.int64)

dataML_split.head(5)
# Out:
#        fecha dia_semana      hora id_tramo               des_tramo  estado  \
# 0 2015-01-01     Jueves  00:15:01     A102          ERNESTO FERRER      37
# 1 2015-01-01     Jueves  00:15:01     A104           EUGENIA VIÑES      33
# 2 2015-01-01     Jueves  00:15:01     A124       GUILLEM DE CASTRO     139
# 3 2015-01-01     Jueves  00:15:01     A127       GUILLEM DE CASTRO     187
# 4 2015-01-01     Jueves  00:15:01     A122  GRAN VIA RAMON Y CAJAL     218
#
#    longitud    latitud   año  mes  dia  horas  minutos  segundos  dias_sem
# 0 -0.354378  39.471478  2015    1    1      0       15         1         4
# 1 -0.325181  39.467414  2015    1    1      0       15         1         4
# 2 -0.383419  39.470396  2015    1    1      0       15         1         4
# 3 -0.384150  39.475677  2015    1    1      0       15         1         4
# 4 -0.335824  39.460994  2015    1    1      0       15         1         4

# %%
#Create new column id from id_tramo replacing column A -> 10 and B -> 20 to int
dataML_split['id_tramos'] = dataML_split['id_tramo'].str.replace(r'^A', '10').str.replace(r'^B', '20').astype(int)
dataML_split.head(5)
# Out:
#        fecha dia_semana      hora id_tramo               des_tramo  estado  \
# 0 2015-01-01     Jueves  00:15:01     A102          ERNESTO FERRER      37
# 1 2015-01-01     Jueves  00:15:01     A104           EUGENIA VIÑES      33
# 2 2015-01-01     Jueves  00:15:01     A124       GUILLEM DE CASTRO     139
# 3 2015-01-01     Jueves  00:15:01     A127       GUILLEM DE CASTRO     187
# 4 2015-01-01     Jueves  00:15:01     A122  GRAN VIA RAMON Y CAJAL     218
#
#    longitud    latitud   año  mes  dia  horas  minutos  segundos  dias_sem  \
# 0 -0.354378  39.471478  2015    1    1      0       15         1         4
# 1 -0.325181  39.467414  2015    1    1      0       15         1         4
# 2 -0.383419  39.470396  2015    1    1      0       15         1         4
# 3 -0.384150  39.475677  2015    1    1      0       15         1         4
# 4 -0.335824  39.460994  2015    1    1      0       15         1         4
#
#    id_tramos
# 0      10102
# 1      10104
# 2      10124
# 3      10127
# 4      10122

# %%
dataML_split[['id_tramo','id_tramos']].head(5)
# Out:
#   id_tramo  id_tramos
# 0     A102      10102
# 1     A104      10104
# 2     A124      10124
# 3     A127      10127
# 4     A122      10122

# %%
day_off = ['2015-01-01','2015-01-06','2015-01-22','2015-03-25','2015-03-28','2015-04-05','2015-04-12',\
          '2015-06-24','2015-08-15','2015-10-12','2015-11-01','2015-12-06','2015-12-08','2015-12-25']
dataML_split['festivo'] = np.where(dataML_split['fecha'].isin(day_off),1,0)

dataML_split[['fecha','festivo']]
# Out:
#               fecha  festivo
# 0        2015-01-01        1
# 1        2015-01-01        1
# 2        2015-01-01        1
# 3        2015-01-01        1
# 4        2015-01-01        1
# ...             ...      ...
# 11899954 2015-12-31        0
# 11899955 2015-12-31        0
# 11899956 2015-12-31        0
# 11899957 2015-12-31        0
# 11899958 2015-12-31        0
#
# [11899959 rows x 2 columns]

# %%
dataML_split[['fecha','dia_semana','dias_sem','festivo']].head(5)
# Out:
#        fecha dia_semana  dias_sem  festivo
# 0 2015-01-01     Jueves         4        1
# 1 2015-01-01     Jueves         4        1
# 2 2015-01-01     Jueves         4        1
# 3 2015-01-01     Jueves         4        1
# 4 2015-01-01     Jueves         4        1

# %%
dataML_split.dtypes
# Out:
# fecha         datetime64[ns]
# dia_semana            object
# hora                  object
# id_tramo              object
# des_tramo             object
# estado                 int64
# longitud             float64
# latitud              float64
# año                    int64
# mes                    int64
# dia                    int64
# horas                  int64
# minutos                int64
# segundos               int64
# dias_sem               int64
# id_tramos              int64
# festivo                int64
# dtype: object

# %%
dataML_splitted = dataML_split[['año','mes','dia','horas','minutos','segundos','dias_sem','id_tramos','festivo','estado']]
dataML_splitted.head(5)
# Out:
#     año  mes  dia  horas  minutos  segundos  dias_sem  id_tramos  festivo  \
# 0  2015    1    1      0       15         1         4      10102        1
# 1  2015    1    1      0       15         1         4      10104        1
# 2  2015    1    1      0       15         1         4      10124        1
# 3  2015    1    1      0       15         1         4      10127        1
# 4  2015    1    1      0       15         1         4      10122        1
#
#    estado
# 0      37
# 1      33
# 2     139
# 3     187
# 4     218

# %%
#Media por fecha
df_media_hora_dia = dataML_splitted.groupby(['año','mes','dia','horas','dias_sem','id_tramos','festivo']).estado.mean()\
                    .to_frame().reset_index()

df_media_red = df_media_hora_dia[df_media_hora_dia['estado'] < 3256.5] #valor anómalo

df_media_red.head(5)
# Out:
#     año  mes  dia  horas  dias_sem  id_tramos  festivo      estado
# 0  2015    1    1      0         4        101        1  419.333333
# 1  2015    1    1      0         4        103        1  129.000000
# 2  2015    1    1      0         4        105        1  521.666667
# 3  2015    1    1      0         4        107        1  370.000000
# 4  2015    1    1      0         4        108        1  281.000000

# %%
df_media_red.rename(columns={'estado':'media'}, inplace=True)
df_media_red
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo       media
# 0        2015    1    1      0         4        101        1  419.333333
# 1        2015    1    1      0         4        103        1  129.000000
# 2        2015    1    1      0         4        105        1  521.666667
# 3        2015    1    1      0         4        107        1  370.000000
# 4        2015    1    1      0         4        108        1  281.000000
# ...       ...  ...  ...    ...       ...        ...      ...         ...
# 3154803  2015   12   31     23         4      20121        0   41.000000
# 3154804  2015   12   31     23         4      20123        0   10.000000
# 3154805  2015   12   31     23         4      20124        0   37.000000
# 3154806  2015   12   31     23         4      20125        0   15.000000
# 3154807  2015   12   31     23         4      20126        0   67.000000
#
# [3008090 rows x 8 columns]

# %%
#Guardamos los datos filtrados anteriormente en un csv
ml_data = 'datos_ML_tramos.csv'
try:
    df_media_red.to_csv(ml_data,sep=';', index=False, header = True)
    print('Archivo Creado Correctamente')
except EmptyDataError as ex:
    print('Datos Vacíos: \n',ex)
except ParserError as ex:
    print('Error Parseo Archivo: \n',ex)
except Exception as ex:
    print('Archivo Creado con Errores: \n',ex)
# Out:
# Archivo Creado Correctamente

# %%
#Cargamos dataset
dataML_tramos = pd.read_csv('/../TFM/Machine_Learning_Data/section_data/datos_ML_tramos.csv',sep=';',engine='python')
dataML_tramos
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo       media
# 0        2015    1    1      0         4        101        1  419.333333
# 1        2015    1    1      0         4        103        1  129.000000
# 2        2015    1    1      0         4        105        1  521.666667
# 3        2015    1    1      0         4        107        1  370.000000
# 4        2015    1    1      0         4        108        1  281.000000
# ...       ...  ...  ...    ...       ...        ...      ...         ...
# 3008085  2015   12   31     23         4      20121        0   41.000000
# 3008086  2015   12   31     23         4      20123        0   10.000000
# 3008087  2015   12   31     23         4      20124        0   37.000000
# 3008088  2015   12   31     23         4      20125        0   15.000000
# 3008089  2015   12   31     23         4      20126        0   67.000000
#
# [3008090 rows x 8 columns]

# %% [markdown]
# **Tramos Análisis**
#
# - A69 - CID, AVENIDA
# - A70 - CID, AVENIDA
# - A71 - CID, AVENIDA
# - A72 - AVDA, CID
#
#
# - A5 - ACCESO BARCELONA [Entre Primado Reig y Blasco Ibáñez]
# - A1 - ACCESO BARCELONA Entre V-21 y Ronda Norte
# - A287 - ACCESO BARCELONA (PASO INFERIOR) [Entre V-21 y Av, Cataluña]
# - A296 - ACCESO BARCELONA RAMAL DE ENTRADA [De V-21 a Rotonda]
# - A297 - ACCESO BARCELONA RAMAL DE SALIDA [De Paso Inferior a V-21]
#
#
# - A27 - AUSIAS MARCH
# - A28 - AUSIAS MARCH
# - A29 - AUSIAS MARCH
#
#
# - A81 - CORTES VALENCIANAS desde GENERAL AVILES hasta LA SAFOR
# - A82 - CORTES VALENCIANA
#
# - A357 - PLAZA DEL AYUNTAMIENTO
#
# - A7 - PASEO ALAMEDA

# %%
#ata_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 101)]
#data_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 1027)]
#data_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 1069)]
#data_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 1082)]
#data_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 10357)]
ata_section_1 = dataML_tramos.loc[(dataML_tramos['id_tramos'] == 107)]
#data_section_1 = dataML_tramos.loc[(dataML_tramos['id'].isin([1069,1070,1071,1072]))]
data_section_1.sort_values(by=['id_tramos'], inplace=True)
data_section_1.reset_index(inplace=True)
data_section_1
# Out:
#       level_0    index   año  mes  dia_mes  horas  dias_sem  id_tramos  \
# 0           0      339  2015    1        1      0         4      10357
# 1        5135     5540  2015    1        1     13         4      10357
# 2        5134      741  2015    1        1      1         4      10357
# 3        5133     1143  2015    1        1      2         4      10357
# 4        5132     1543  2015    1        1      3         4      10357
# ...       ...      ...   ...  ...      ...    ...       ...        ...
# 7688     2557  3006443  2015   12       31     16         4      10357
# 7689     2556  3006842  2015   12       31     17         4      10357
# 7690     2555  3007237  2015   12       31     18         4      10357
# 7691     2403  2822932  2015   12       11      0         5      10357
# 7692     7692  3008031  2015   12       31     23         4      10357
#
#       festivo        media     media-24
# 0           1   539.666667     0.000000
# 1           1  1319.250000  1115.458333
# 2           1  2712.666667  1088.878472
# 3           1  1918.333333  1012.642361
# 4           1  1338.000000   965.892361
# ...       ...          ...          ...
# 7688        0  1470.000000  1840.500000
# 7689        0  1400.250000  1803.875000
# 7690        0  1511.000000  1767.947917
# 7691        0   392.500000  1300.565972
# 7692        0   393.000000  1328.947917
#
# [7693 rows x 11 columns]

# %%
data_section_1['media-24'] = data_section_1['media'].rolling(window=24,center=False).mean()
data_section_1
# Out:
#       level_0    index   año  mes  dia_mes  horas  dias_sem  id_tramos  \
# 0           0      339  2015    1        1      0         4      10357
# 1        5135     5540  2015    1        1     13         4      10357
# 2        5134      741  2015    1        1      1         4      10357
# 3        5133     1143  2015    1        1      2         4      10357
# 4        5132     1543  2015    1        1      3         4      10357
# ...       ...      ...   ...  ...      ...    ...       ...        ...
# 7688     2557  3006443  2015   12       31     16         4      10357
# 7689     2556  3006842  2015   12       31     17         4      10357
# 7690     2555  3007237  2015   12       31     18         4      10357
# 7691     2403  2822932  2015   12       11      0         5      10357
# 7692     7692  3008031  2015   12       31     23         4      10357
#
#       festivo        media     media-24
# 0           1   539.666667          NaN
# 1           1  1319.250000          NaN
# 2           1  2712.666667          NaN
# 3           1  1918.333333          NaN
# 4           1  1338.000000          NaN
# ...       ...          ...          ...
# 7688        0  1470.000000  1724.767361
# 7689        0  1400.250000  1688.027778
# 7690        0  1511.000000  1644.180556
# 7691        0   392.500000  1544.055556
# 7692        0   393.000000  1462.201389
#
# [7693 rows x 11 columns]

# %%
data_section_1['media-24'] = data_section_1['media-24'].fillna(0)
data_section_1.head(30)
# Out:
#     level_0  index   año  mes  dia_mes  horas  dias_sem  id_tramos  festivo  \
# 0         0    339  2015    1        1      0         4      10357        1
# 1      5135   5540  2015    1        1     13         4      10357        1
# 2      5134    741  2015    1        1      1         4      10357        1
# 3      5133   1143  2015    1        1      2         4      10357        1
# 4      5132   1543  2015    1        1      3         4      10357        1
# 5      5131   1945  2015    1        1      4         4      10357        1
# 6      5130   2346  2015    1        1      5         4      10357        1
# 7      5129   2748  2015    1        1      6         4      10357        1
# 8      5128   3150  2015    1        1      7         4      10357        1
# 9      5127   3550  2015    1        1      8         4      10357        1
# 10     5126   3951  2015    1        1      9         4      10357        1
# 11     5125   4348  2015    1        1     10         4      10357        1
# 12     5124   4744  2015    1        1     11         4      10357        1
# 13     5136  23454  2015    1        3     10         6      10357        0
# 14     5123   5141  2015    1        1     12         4      10357        1
# 15     5121  11135  2015    1        2      3         5      10357        0
# 16     5120   6336  2015    1        1     15         4      10357        1
# 17     5119   6737  2015    1        1     16         4      10357        1
# 18     5118   7138  2015    1        1     17         4      10357        1
# 19     5117   7535  2015    1        1     18         4      10357        1
# 20     5116   7928  2015    1        1     19         4      10357        1
# 21     5115   8324  2015    1        1     20         4      10357        1
# 22     5114   8724  2015    1        1     21         4      10357        1
# 23     5113   9125  2015    1        1     22         4      10357        1
# 24     5112   9527  2015    1        1     23         4      10357        1
# 25     5111   9929  2015    1        2      0         5      10357        0
# 26     5110  10331  2015    1        2      1         5      10357        0
# 27     5122   5938  2015    1        1     14         4      10357        1
# 28     5109  10733  2015    1        2      2         5      10357        0
# 29     5137  11536  2015    1        2      4         5      10357        0
#
#           media     media-24
# 0    539.666667     0.000000
# 1   1319.250000     0.000000
# 2   2712.666667     0.000000
# 3   1918.333333     0.000000
# 4   1338.000000     0.000000
# 5   1042.666667     0.000000
# 6    904.000000     0.000000
# 7    820.000000     0.000000
# 8    766.500000     0.000000
# 9    857.000000     0.000000
# 10   940.000000     0.000000
# 11   627.500000     0.000000
# 12   579.000000     0.000000
# 13   699.000000     0.000000
# 14   719.000000     0.000000
# 15   539.666667     0.000000
# 16  1064.250000     0.000000
# 17   973.666667     0.000000
# 18  1372.500000     0.000000
# 19  1676.500000     0.000000
# 20  1560.500000     0.000000
# 21  1286.000000     0.000000
# 22  1048.000000     0.000000
# 23   684.750000  1082.850694
# 24   423.500000  1078.010417
# 25   681.333333  1051.430556
# 26   883.000000   975.194444
# 27  1597.750000   961.836806
# 28   796.333333   939.267361
# 29   647.333333   922.795139

# %%
data_section_1.rename(columns={'dia':'dia_mes','dias': 'dia_semana', 'id': 'id_tramo','estado':'media',}, inplace=True)
data_section_1.head(5)
# Out:
#    level_0  index   año  mes  dia_mes  horas  dias_sem  id_tramos  festivo  \
# 0        0    339  2015    1        1      0         4      10357        1
# 1     5135   5540  2015    1        1     13         4      10357        1
# 2     5134    741  2015    1        1      1         4      10357        1
# 3     5133   1143  2015    1        1      2         4      10357        1
# 4     5132   1543  2015    1        1      3         4      10357        1
#
#          media  media-24
# 0   539.666667       0.0
# 1  1319.250000       0.0
# 2  2712.666667       0.0
# 3  1918.333333       0.0
# 4  1338.000000       0.0

# %%
data_section_1.count()
# Out:
# level_0      7693
# index        7693
# año          7693
# mes          7693
# dia_mes      7693
# horas        7693
# dias_sem     7693
# id_tramos    7693
# festivo      7693
# media        7693
# media-24     7693
# dtype: int64

# %%
df_test = data_section_1.copy()
del df_test['index']
df_test.head(5)
# Out:
#    level_0   año  mes  dia_mes  horas  dias_sem  id_tramos  festivo  \
# 0        0  2015    1        1      0         4      10357        1
# 1     5135  2015    1        1     13         4      10357        1
# 2     5134  2015    1        1      1         4      10357        1
# 3     5133  2015    1        1      2         4      10357        1
# 4     5132  2015    1        1      3         4      10357        1
#
#          media  media-24
# 0   539.666667       0.0
# 1  1319.250000       0.0
# 2  2712.666667       0.0
# 3  1918.333333       0.0
# 4  1338.000000       0.0

# %%
df_test[50:57]
# Out:
#     level_0   año  mes  dia_mes  horas  dias_sem  id_tramos  festivo   media  \
# 50     5146  2015    1        3      1         6      10357        0  909.25
# 51     5145  2015    1        3      2         6      10357        0  819.00
# 52     5144  2015    1        3      3         6      10357        0  590.50
# 53     5143  2015    1        3      4         6      10357        0  588.75
# 54     5142  2015    1        3      5         6      10357        0  436.50
# 55     5141  2015    1        3      6         6      10357        0  427.50
# 56     5140  2015    1        3      7         6      10357        0  494.25
#
#        media-24
# 50  1242.954861
# 51  1210.506944
# 52  1201.930556
# 53  1199.489583
# 54  1191.968750
# 55  1132.045139
# 56  1134.444444

# %%
df_test.dtypes
# Out:
# level_0        int64
# año            int64
# mes            int64
# dia_mes        int64
# horas          int64
# dias_sem       int64
# id_tramos      int64
# festivo        int64
# media        float64
# media-24     float64
# dtype: object

# %%
df_test[['mes','dia_mes','horas','dias_sem','festivo','media-24','media']].dtypes
# Out:
# mes           int64
# dia_mes       int64
# horas         int64
# dias_sem      int64
# festivo       int64
# media-24    float64
# media       float64
# dtype: object

# %%
df_test.count()
# Out:
# level_0      7693
# año          7693
# mes          7693
# dia_mes      7693
# horas        7693
# dias_sem     7693
# id_tramos    7693
# festivo      7693
# media        7693
# media-24     7693
# dtype: int64

# %%
#Correlación de las variables con respecto a estado
df_corr = df_test[['mes','dia_mes','horas','dias_sem','festivo','media-24','media']]
fig, ax = plt.subplots(figsize=(14,7))
sns.heatmap(data=df_corr.astype({'media': 'int32'}).corr(),annot=True,vmax=1.0, cmap='coolwarm',\
            linewidths=.5, ax=ax);

# %%
#Generamos las horas a 31/12/2015
start = '2015-12-31 00:00'
dates_24 = pd.date_range(start,freq='H',periods=24).to_frame()
dates_24.rename(columns={0: 'Fecha'},inplace = True)
dates_24.head(5)
# Out:
#                                   Fecha
# 2015-12-31 00:00:00 2015-12-31 00:00:00
# 2015-12-31 01:00:00 2015-12-31 01:00:00
# 2015-12-31 02:00:00 2015-12-31 02:00:00
# 2015-12-31 03:00:00 2015-12-31 03:00:00
# 2015-12-31 04:00:00 2015-12-31 04:00:00

# %%
#Generamos las horas a 01/01/2016
start = '2016-01-01 00:00'
pred_dates_24 = pd.date_range(start,freq='H',periods=24).to_frame()
pred_dates_24.rename(columns={0: 'Fecha'},inplace = True)
pred_dates_24.head(5)
# Out:
#                                   Fecha
# 2016-01-01 00:00:00 2016-01-01 00:00:00
# 2016-01-01 01:00:00 2016-01-01 01:00:00
# 2016-01-01 02:00:00 2016-01-01 02:00:00
# 2016-01-01 03:00:00 2016-01-01 03:00:00
# 2016-01-01 04:00:00 2016-01-01 04:00:00

# %% [markdown]
# ### Baseline Model

# %%
def baseline_model(X_dummy,y_dummy,v_test_size):
    X_train,X_test,y_train,y_test=train_test_split(X_dummy,y_dummy,test_size=v_test_size,random_state=42)
    
    #print('Media Train: ',round(y_train.mean(),2))
    #print('Media Test : ',round(y_test.mean(),2))
    
    
    #predice la media de los datos de entrenamiento
    
    #Modelo Baseline
    lm_dummy_mean = DummyRegressor(strategy = 'mean').fit(X_train, y_train)
    
    y_predict_dummy_mean = lm_dummy_mean.predict(X_test)
    
    rmse_media = []
    rmse_dummy_X = round((sqrt(mean_squared_error(y_test,y_predict_dummy_mean))),2)
    rmse_media.append(rmse_dummy_X)
    
    return rmse_media

# %%
#X_dummy = df_test[['mes','dia_mes','horas','dia_semana','id_tramo','festivo','media-24']]
X_dummy = df_test[['mes','dia_mes','horas','dias_sem','festivo','media-24']]
y_dummy = df_test['media']

stored = []

counter = 0
for x_d,y_d,z_d in zip(range(0,3),range(0,3),range(0,3)):
    counter +=1
    print('Iteración :',counter)

    x_1 = baseline_model(X_dummy,y_dummy,0.10)
    stored.append(x_1)
    x_2 = baseline_model(X_dummy,y_dummy,0.20)
    stored.append(x_2)
    x_3 = baseline_model(X_dummy,y_dummy,0.30)
    stored.append(x_3)

print(stored)
# Out:
# Iteración : 1
# Iteración : 2
# Iteración : 3
# [[933.76], [946.85], [946.77], [933.76], [946.85], [946.77], [933.76], [946.85], [946.77]]

# %%
dummy_df = pd.DataFrame(data=stored,columns=['rmse_dummy'])
dummy_df
# Out:
#    rmse_dummy
# 0      933.76
# 1      946.85
# 2      946.77
# 3      933.76
# 4      946.85
# 5      946.77
# 6      933.76
# 7      946.85
# 8      946.77

# %%
dummy_rme_main_mean = dummy_df.mean()
dum = round(dummy_rme_main_mean,2)
print(dum)
# Out:
# rmse_dummy    942.46
# dtype: float64

# %% [markdown]
# ### k-Fold Cross-Validation

# %%
def cross_validation(X_cross,y_cross,c_test_size):
    global modelo_rf
    global X_train,X_test,y_train,y_test
    
    X_train,X_test,y_train,y_test=train_test_split(X_cross,y_cross,test_size=c_test_size,random_state=42)
    
    #print('Media Train: ',round(y_train.mean(),2))
    #print('Media Test : ',round(y_test.mean(),2))
    
    #Regresión Lineal
    modelo_rl = Ridge(alpha=1.0)
 
    #KNN
    modelo_knn = KNeighborsRegressor(n_neighbors = 2)

    #Random Forest
    modelo_rf = RandomForestRegressor(n_estimators=100,max_depth=8,bootstrap=True,verbose=0,\
                                      max_features = 'auto',random_state = 42)

    #Naive Bayes
    modelo_nb = GaussianNB()
    
    #Modelo Redes Neuronales
    model = Sequential()
    model.add(Dense(12, activation='relu', kernel_initializer='he_normal',input_dim=6)) #capa oculta
    model.add( Dropout(0.5) ) #evitar overfitting

    model.add(Dense(8,activation='relu', kernel_initializer='he_normal')) #capa oculta
    model.add( Dropout(0.5) )

    model.add(Dense(4,activation='relu', kernel_initializer='he_normal')) #capa oculta
    model.add( Dropout(0.5) )

    model.add(Dense(1,activation='sigmoid')) #capa salida
    model.add( Dropout(0.5) )

    #Compilación modelo NN
    model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])
    
    #Ejecución modelo NN
    model_nn = KerasClassifier(model,batch_size=500,epochs=30,verbose=1,shuffle=True)
    
    #definimos método cross_validation con kfolds
    cv = KFold(n_splits=10, random_state=1, shuffle=True) 
    
    #evaluamos los modelos con cross_val_score
    scores_lr = cross_val_score(modelo_rl, X_train, y_train, scoring='neg_mean_squared_error',cv=cv)
    scores_knn = cross_val_score(modelo_knn, X_train, y_train, scoring='neg_mean_squared_error',cv=cv)
    scores_rf = cross_val_score(modelo_rf, X_train, y_train, scoring='neg_mean_squared_error',cv=cv)
    scores_nb = cross_val_score(modelo_nb, X_train.astype(int), y_train.astype(int), scoring='neg_mean_squared_error',cv=cv)
    scores_nn = model.evaluate(X_train, y_train)
    
    rmse_cross = []

    rmse_lr = sqrt(mean(absolute(scores_lr)))
    rmse_cross.append(rmse_lr)

    rmse_knn = sqrt(mean(absolute(scores_knn)))
    rmse_cross.append(rmse_knn)

    rmse_rf = sqrt(mean(absolute(scores_rf)))
    rmse_cross.append(rmse_rf)

    rmse_nb = sqrt(mean(absolute(scores_nb)))
    rmse_cross.append(rmse_nb)

    rmse_nn = sqrt(mean(absolute(scores_nn)))
    rmse_cross.append(rmse_nn)
    
    
    #predicciones en test
    #pred_rl = cross_val_predict(modelo_rl, X_cross, y_cross, cv=5)
    modelo_rl.fit(X_train, y_train)
    pred_rl = modelo_rl.predict(X_test)
    
    #pred_knn = cross_val_predict(modelo_knn, X_cross, y_cross, cv=5)
    modelo_knn.fit(X_train, y_train)
    pred_knn = modelo_knn.predict(X_test)
    
    #pred_rf = cross_val_predict(modelo_rf, X_cross, y_cross, cv=5)
    modelo_rf.fit(X_train, y_train)
    global pred_rf
    pred_rf = modelo_rf.predict(X_test)
    
    #pred_nb = cross_val_predict(modelo_nb, X_cross.astype(int), y_cross.astype(int), cv=5)
    modelo_nb.fit(X_train.astype(int), y_train.astype(int))
    pred_nb = modelo_nb.predict(X_test.astype(int))
    
    pred_nn = model.predict(X_test)
    
    return rmse_cross

# %%
#X_cross = df_test[['mes','dia_mes','horas','dia_semana','id_tramo','festivo','media-24']]
X_cross = df_test[['mes','dia_mes','horas','dias_sem','festivo','media-24']]
y_cross = df_test['media']

# %%
cross_1 = []
cross_2 = []
cross_3 = []

c = 0
for x,y,z in zip(range(0,3),range(0,3),range(0,3)):
    c +=1
    print('Iteración :',c)
    
    x = cross_validation(X_cross,y_cross,0.10)
    cross_1.append(x)
    
    y = cross_validation(X_cross,y_cross,0.20)
    cross_2.append(y)
    
    z = cross_validation(X_cross,y_cross,0.30)
    cross_3.append(z)
# Out:
# Iteración : 1
# 217/217 [==============================] - 0s 624us/step - loss: 3296626.5000 - mse: 3296626.5000
# 193/193 [==============================] - 0s 623us/step - loss: 3290128.7500 - mse: 3290128.7500
# 169/169 [==============================] - 0s 672us/step - loss: 3292654.2500 - mse: 3292654.2500
# Iteración : 2
# 217/217 [==============================] - 0s 631us/step - loss: 3296626.7500 - mse: 3296626.7500
# 193/193 [==============================] - 0s 639us/step - loss: 3287051.7500 - mse: 3287051.7500
# 169/169 [==============================] - 0s 644us/step - loss: 3292658.0000 - mse: 3292658.0000
# Iteración : 3
# 217/217 [==============================] - 0s 633us/step - loss: 3296628.2500 - mse: 3296628.2500
# 193/193 [==============================] - 0s 638us/step - loss: 3287604.7500 - mse: 3287604.7500
# 169/169 [==============================] - 0s 654us/step - loss: 3289581.2500 - mse: 3289581.2500

# %%
cross_merged = [cross_1,cross_2,cross_3]

cross_df = pd.DataFrame(np.concatenate(cross_merged),columns=['RL','KNN','RF','NB','NN'])
cross_df
# Out:
#            RL         KNN          RF          NB           NN
# 0  774.550099  723.747802  434.687219  756.899723  1815.661450
# 1  774.550099  723.747802  434.687219  756.899723  1815.661519
# 2  774.550099  723.747802  434.687219  756.899723  1815.661932
# 3  775.045900  731.839253  434.861281  774.422610  1813.871205
# 4  775.045900  731.839253  434.861281  774.422610  1813.022821
# 5  775.045900  731.839253  434.861281  774.422610  1813.175322
# 6  776.670065  729.634183  438.352122  777.191541  1814.567235
# 7  776.670065  729.634183  438.352122  777.191541  1814.568268
# 8  776.670065  729.634183  438.352122  777.191541  1813.720279

# %%
df_cross_mean = [cross_df.mean()]

df_mean = pd.DataFrame(df_cross_mean)
df_mean.T
# Out:
#                0
# RL    775.422021
# KNN   728.407079
# RF    435.966874
# NB    769.504625
# NN   1814.434448

# %% [markdown]
# ***Tramo 101***

# %%
#Tramo 101
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_101 = [949.16,757.34,853.86,481.50,807.11,1545.49]

zip_101 = zip(columnas_rmse,rmse_modelos_101)
df_101 = pd.DataFrame(zip_101, columns = ['Modelo' , 'RMSE'])
df_101
# Out:
#      Modelo     RMSE
# 0  Baseline   949.16
# 1        RL   757.34
# 2       KNN   853.86
# 3        RF   481.50
# 4        NB   807.11
# 5        NN  1545.49

# %%
(df_101
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Acceso V-21'))
# Out:
# <style  type="text/css" >
# #T_e52ae_row0_col1{
#             background-color:  #65c0cb;
#             color:  #000000;
#         }#T_e52ae_row1_col1{
#             background-color:  #2d8fbf;
#             color:  #000000;
#         }#T_e52ae_row2_col1{
#             background-color:  #47abcf;
#             color:  #000000;
#         }#T_e52ae_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_e52ae_row4_col1{
#             background-color:  #3b9dc7;
#             color:  #000000;
#         }#T_e52ae_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_e52ae_" ><caption>Acceso V-21</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e52ae_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e52ae_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_e52ae_row0_col1" class="data row0 col1" >949.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_e52ae_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e52ae_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_e52ae_row1_col1" class="data row1 col1" >757.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_e52ae_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e52ae_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_e52ae_row2_col1" class="data row2 col1" >853.860000</td>
#             </tr>
#             <tr>
#                         <th id="T_e52ae_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e52ae_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_e52ae_row3_col1" class="data row3 col1" >481.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_e52ae_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e52ae_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_e52ae_row4_col1" class="data row4 col1" >807.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_e52ae_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e52ae_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_e52ae_row5_col1" class="data row5 col1" >1545.490000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ***Tramo 1027***

# %%
#Tramo 1027
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_1027 = [999.98,755.25,830.55,487.51,802.54,1747.24]

zip_1027 = zip(columnas_rmse,rmse_modelos_1027)
df_1027 = pd.DataFrame(zip_1027, columns = ['Modelo' , 'RMSE'])
df_1027.round(decimals=2)
df_1027
# Out:
#      Modelo     RMSE
# 0  Baseline   999.98
# 1        RL   755.25
# 2       KNN   830.55
# 3        RF   487.51
# 4        NB   802.54
# 5        NN  1747.24

# %%
(df_1027
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Av. Asias March'))
# Out:
# <style  type="text/css" >
# #T_d693b_row0_col1{
#             background-color:  #5abacf;
#             color:  #000000;
#         }#T_d693b_row1_col1{
#             background-color:  #2081b8;
#             color:  #000000;
#         }#T_d693b_row2_col1{
#             background-color:  #3192c1;
#             color:  #000000;
#         }#T_d693b_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_d693b_row4_col1{
#             background-color:  #2b8cbe;
#             color:  #000000;
#         }#T_d693b_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_d693b_" ><caption>Av. Asias March</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d693b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d693b_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_d693b_row0_col1" class="data row0 col1" >999.980000</td>
#             </tr>
#             <tr>
#                         <th id="T_d693b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d693b_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_d693b_row1_col1" class="data row1 col1" >755.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_d693b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d693b_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_d693b_row2_col1" class="data row2 col1" >830.550000</td>
#             </tr>
#             <tr>
#                         <th id="T_d693b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d693b_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_d693b_row3_col1" class="data row3 col1" >487.510000</td>
#             </tr>
#             <tr>
#                         <th id="T_d693b_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d693b_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_d693b_row4_col1" class="data row4 col1" >802.540000</td>
#             </tr>
#             <tr>
#                         <th id="T_d693b_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d693b_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_d693b_row5_col1" class="data row5 col1" >1747.240000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ***Tramo 1069***

# %%
#Tramo 1069
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_1069 = [1044.12,844.359626,842.557237,487.860484,802.483676,1929.358206]

zip_1069 = zip(columnas_rmse,rmse_modelos_1069)
df_1069 = pd.DataFrame(zip_1069, columns = ['Modelo' , 'RMSE'])
df_1069.round(decimals=2)
df_1069
# Out:
#      Modelo         RMSE
# 0  Baseline  1044.120000
# 1        RL   844.359626
# 2       KNN   842.557237
# 3        RF   487.860484
# 4        NB   802.483676
# 5        NN  1929.358206

# %%
(df_1069
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Av. del Cid'))
# Out:
# <style  type="text/css" >
# #T_3a034_row0_col1{
#             background-color:  #51b5d2;
#             color:  #000000;
#         }#T_3a034_row1_col1{
#             background-color:  #2a8bbe;
#             color:  #000000;
#         }#T_3a034_row2_col1{
#             background-color:  #298abd;
#             color:  #000000;
#         }#T_3a034_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_3a034_row4_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_3a034_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_3a034_" ><caption>Av. del Cid</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a034_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3a034_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_3a034_row0_col1" class="data row0 col1" >1044.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_3a034_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3a034_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_3a034_row1_col1" class="data row1 col1" >844.359626</td>
#             </tr>
#             <tr>
#                         <th id="T_3a034_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3a034_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_3a034_row2_col1" class="data row2 col1" >842.557237</td>
#             </tr>
#             <tr>
#                         <th id="T_3a034_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3a034_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_3a034_row3_col1" class="data row3 col1" >487.860484</td>
#             </tr>
#             <tr>
#                         <th id="T_3a034_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3a034_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_3a034_row4_col1" class="data row4 col1" >802.483676</td>
#             </tr>
#             <tr>
#                         <th id="T_3a034_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3a034_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_3a034_row5_col1" class="data row5 col1" >1929.358206</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ***Tramo 1082***

# %%
#Tramo 1082
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_1082 = [924.67,732.723166,823.006681,452.358676,747.654927,1536.838036]

zip_1082 = zip(columnas_rmse,rmse_modelos_1082)
df_1082 = pd.DataFrame(zip_1082, columns = ['Modelo' , 'RMSE'])
df_1082.round(decimals=2)
df_1082
# Out:
#      Modelo         RMSE
# 0  Baseline   924.670000
# 1        RL   732.723166
# 2       KNN   823.006681
# 3        RF   452.358676
# 4        NB   747.654927
# 5        NN  1536.838036

# %%
(df_1082
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Av. Cortes Valencianas'))
# Out:
# <style  type="text/css" >
# #T_32ba3_row0_col1{
#             background-color:  #64bfcc;
#             color:  #000000;
#         }#T_32ba3_row1_col1{
#             background-color:  #2d8fbf;
#             color:  #000000;
#         }#T_32ba3_row2_col1{
#             background-color:  #45a8cd;
#             color:  #000000;
#         }#T_32ba3_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_32ba3_row4_col1{
#             background-color:  #3192c1;
#             color:  #000000;
#         }#T_32ba3_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_32ba3_" ><caption>Av. Cortes Valencianas</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32ba3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_32ba3_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_32ba3_row0_col1" class="data row0 col1" >924.670000</td>
#             </tr>
#             <tr>
#                         <th id="T_32ba3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_32ba3_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_32ba3_row1_col1" class="data row1 col1" >732.723166</td>
#             </tr>
#             <tr>
#                         <th id="T_32ba3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_32ba3_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_32ba3_row2_col1" class="data row2 col1" >823.006681</td>
#             </tr>
#             <tr>
#                         <th id="T_32ba3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_32ba3_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_32ba3_row3_col1" class="data row3 col1" >452.358676</td>
#             </tr>
#             <tr>
#                         <th id="T_32ba3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_32ba3_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_32ba3_row4_col1" class="data row4 col1" >747.654927</td>
#             </tr>
#             <tr>
#                         <th id="T_32ba3_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_32ba3_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_32ba3_row5_col1" class="data row5 col1" >1536.838036</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ***Tramo 10357***

# %%
#Tramo 10357
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_10357 = [955.17,772.040754,765.008959,435.520586,755.833491,1816.395116]

zip_10357 = zip(columnas_rmse,rmse_modelos_10357)
df_10357 = pd.DataFrame(zip_10357, columns = ['Modelo' , 'RMSE'])
df_10357['RMSE'].round(decimals=2)
df_10357
# Out:
#      Modelo         RMSE
# 0  Baseline   955.170000
# 1        RL   772.040754
# 2       KNN   765.008959
# 3        RF   435.520586
# 4        NB   755.833491
# 5        NN  1816.395116

# %%
(df_10357
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Plaza Ayuntamiento'))
# Out:
# <style  type="text/css" >
# #T_8ea38_row0_col1{
#             background-color:  #4fb3d3;
#             color:  #000000;
#         }#T_8ea38_row1_col1{
#             background-color:  #298abd;
#             color:  #000000;
#         }#T_8ea38_row2_col1{
#             background-color:  #2889bc;
#             color:  #000000;
#         }#T_8ea38_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_8ea38_row4_col1{
#             background-color:  #2687bb;
#             color:  #000000;
#         }#T_8ea38_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_8ea38_" ><caption>Plaza Ayuntamiento</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ea38_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8ea38_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_8ea38_row0_col1" class="data row0 col1" >955.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea38_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8ea38_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_8ea38_row1_col1" class="data row1 col1" >772.040754</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea38_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8ea38_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_8ea38_row2_col1" class="data row2 col1" >765.008959</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea38_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8ea38_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_8ea38_row3_col1" class="data row3 col1" >435.520586</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea38_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8ea38_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_8ea38_row4_col1" class="data row4 col1" >755.833491</td>
#             </tr>
#             <tr>
#                         <th id="T_8ea38_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8ea38_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_8ea38_row5_col1" class="data row5 col1" >1816.395116</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ***Tramo 107***

# %%
#Tramo 107
columnas_rmse =['Baseline','RL','KNN','RF','NB','NN']
rmse_modelos_107 = [476.05,480.75,765.008959,288.63,519.72,1187.80]

zip_107 = zip(columnas_rmse,rmse_modelos_107)
df_107 = pd.DataFrame(zip_107, columns = ['Modelo' , 'RMSE'])
df_107['RMSE'].round(decimals=2)
df_107
# Out:
#      Modelo         RMSE
# 0  Baseline   476.050000
# 1        RL   480.750000
# 2       KNN   765.008959
# 3        RF   288.630000
# 4        NB   519.720000
# 5        NN  1187.800000

# %%
(df_107
 .style
 .background_gradient(subset=['RMSE'], cmap='GnBu_r')
 .set_caption('Paseo Alameda'))
# Out:
# <style  type="text/css" >
# #T_d32ed_row0_col1{
#             background-color:  #1f80b8;
#             color:  #000000;
#         }#T_d32ed_row1_col1{
#             background-color:  #2081b8;
#             color:  #000000;
#         }#T_d32ed_row2_col1{
#             background-color:  #86d0c0;
#             color:  #000000;
#         }#T_d32ed_row3_col1{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_d32ed_row4_col1{
#             background-color:  #2c8ebf;
#             color:  #000000;
#         }#T_d32ed_row5_col1{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }</style><table id="T_d32ed_" ><caption>Paseo Alameda</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Modelo</th>        <th class="col_heading level0 col1" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d32ed_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d32ed_row0_col0" class="data row0 col0" >Baseline</td>
#                         <td id="T_d32ed_row0_col1" class="data row0 col1" >476.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_d32ed_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d32ed_row1_col0" class="data row1 col0" >RL</td>
#                         <td id="T_d32ed_row1_col1" class="data row1 col1" >480.750000</td>
#             </tr>
#             <tr>
#                         <th id="T_d32ed_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d32ed_row2_col0" class="data row2 col0" >KNN</td>
#                         <td id="T_d32ed_row2_col1" class="data row2 col1" >765.008959</td>
#             </tr>
#             <tr>
#                         <th id="T_d32ed_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d32ed_row3_col0" class="data row3 col0" >RF</td>
#                         <td id="T_d32ed_row3_col1" class="data row3 col1" >288.630000</td>
#             </tr>
#             <tr>
#                         <th id="T_d32ed_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d32ed_row4_col0" class="data row4 col0" >NB</td>
#                         <td id="T_d32ed_row4_col1" class="data row4 col1" >519.720000</td>
#             </tr>
#             <tr>
#                         <th id="T_d32ed_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d32ed_row5_col0" class="data row5 col0" >NN</td>
#                         <td id="T_d32ed_row5_col1" class="data row5 col1" >1187.800000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Predicciones Mejor Modelo

# %% [markdown]
# **Tramo 101 24 Horas**

# %%
df_predRF_101 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_101
# Out:
#            Actual   Predicción
# 3395  1280.000000  1424.304360
# 1114  2582.500000  1673.302604
# 351   1794.000000  1868.555119
# 1983   685.000000   388.808410
# 2320   535.750000   522.619322
# ...           ...          ...
# 1456   151.666667   273.909744
# 2899  1457.250000  1399.935999
# 3652  1222.750000  1468.920684
# 3250   242.500000   563.082056
# 942    694.000000   502.370677
#
# [1122 rows x 2 columns]

# %%
plt.scatter(df_predRF_101['Actual'],df_predRF_101['Predicción'])

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_101 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_101.csv',sep=';',engine='python')
dataML_pred_tramos_101.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo     media-24
# 0  2016    1        1      0         5        101        1  2026.596642
# 1  2016    1        1      1         5        101        1  2040.274019
# 2  2016    1        1      2         5        101        1  2046.888176
# 3  2016    1        1      3         5        101        1  2050.665962
# 4  2016    1        1      4         5        101        1  2056.294852

# %%
#Predicciones 24 Horas
new_predictions_101 = modelo_rf.predict(dataML_pred_tramos_101[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_101
# Out:
# array([1051.59170235,  899.83251821,  544.72348184,  522.25162246,
#         526.23891228,  577.62644979,  809.70001018, 2004.12072201,
#        1963.90427929, 2032.33981557, 2217.17013328, 2342.86534031,
#        2157.34252707, 2187.14431575, 2367.34109936, 2562.08614992,
#        2579.26993379, 2595.12547582, 2602.42405015, 2572.8093731 ,
#        2575.65424867, 2575.65424867, 2039.86157971,  948.09554803])

# %%
#unimos las predicciones con las horas
data_pred_rf_101 = pd.DataFrame(new_predictions_101,columns = ['media'])
data_pred_rf_101.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_101)))
data_pred_rf_101.set_index('Hora',inplace=True)
data_pred_rf_101.head(5)
# Out:
#             media
# Hora
# 0     1051.591702
# 1      899.832518
# 2      544.723482
# 3      522.251622
# 4      526.238912

# %%
(data_pred_rf_101
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 .set_caption('Predicciones 24H Acceso V-21'))
# Out:
# <style  type="text/css" >
# #T_2d225_row0_col0{
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }#T_2d225_row1_col0{
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }#T_2d225_row2_col0{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_2d225_row3_col0,#T_2d225_row4_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_2d225_row5_col0{
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }#T_2d225_row6_col0{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_2d225_row7_col0{
#             background-color:  #2c944c;
#             color:  #000000;
#         }#T_2d225_row8_col0{
#             background-color:  #309950;
#             color:  #000000;
#         }#T_2d225_row9_col0{
#             background-color:  #29914a;
#             color:  #000000;
#         }#T_2d225_row10_col0{
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }#T_2d225_row11_col0{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_2d225_row12_col0{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_2d225_row13_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_2d225_row14_col0{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_2d225_row15_col0{
#             background-color:  #00491d;
#             color:  #f1f1f1;
#         }#T_2d225_row16_col0{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_2d225_row17_col0,#T_2d225_row18_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_2d225_row19_col0,#T_2d225_row20_col0,#T_2d225_row21_col0{
#             background-color:  #00481d;
#             color:  #f1f1f1;
#         }#T_2d225_row22_col0{
#             background-color:  #289049;
#             color:  #000000;
#         }#T_2d225_row23_col0{
#             background-color:  #d2edcc;
#             color:  #000000;
#         }</style><table id="T_2d225_" ><caption>Predicciones 24H Acceso V-21</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2d225_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2d225_row0_col0" class="data row0 col0" >1051.591702</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2d225_row1_col0" class="data row1 col0" >899.832518</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2d225_row2_col0" class="data row2 col0" >544.723482</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2d225_row3_col0" class="data row3 col0" >522.251622</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2d225_row4_col0" class="data row4 col0" >526.238912</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2d225_row5_col0" class="data row5 col0" >577.626450</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2d225_row6_col0" class="data row6 col0" >809.700010</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2d225_row7_col0" class="data row7 col0" >2004.120722</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2d225_row8_col0" class="data row8 col0" >1963.904279</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2d225_row9_col0" class="data row9 col0" >2032.339816</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2d225_row10_col0" class="data row10 col0" >2217.170133</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2d225_row11_col0" class="data row11 col0" >2342.865340</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2d225_row12_col0" class="data row12 col0" >2157.342527</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2d225_row13_col0" class="data row13 col0" >2187.144316</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2d225_row14_col0" class="data row14 col0" >2367.341099</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_2d225_row15_col0" class="data row15 col0" >2562.086150</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_2d225_row16_col0" class="data row16 col0" >2579.269934</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_2d225_row17_col0" class="data row17 col0" >2595.125476</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_2d225_row18_col0" class="data row18 col0" >2602.424050</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_2d225_row19_col0" class="data row19 col0" >2572.809373</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_2d225_row20_col0" class="data row20 col0" >2575.654249</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_2d225_row21_col0" class="data row21 col0" >2575.654249</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_2d225_row22_col0" class="data row22 col0" >2039.861580</td>
#             </tr>
#             <tr>
#                         <th id="T_2d225_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_2d225_row23_col0" class="data row23 col0" >948.095548</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_101 = data_pred_rf_101.mean()
print(media_RF_24_101)

max_RF_24_101 = data_pred_rf_101.max()
print(max_RF_24_101)

min_RF_24_101 = data_pred_rf_101.min()
print(min_RF_24_101)
# Out:
# media    1802.298897
# dtype: float64
# media    2602.42405
# dtype: float64
# media    522.251622
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
#plt.margins(x=0,y=0)
sns.lineplot(data=data_pred_rf_101).set(title='Predicciones 24 Horas Acceso Barcelona')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Acceso Barcelona')]

# %%
#Medias tramo 101 31/12/2015
df_101 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 101)]

new_row_0 = [2015, 12, 31,0,4,101,0,729.000000]
new_row_1 = [2015, 12, 31,3,4,101,0,322.000000]
new_row_2 = [2015, 12, 31,6,4,101,0,854.450000]
new_row_3 = [2015, 12, 31,7,4,101,0,1365.750000]
new_row_4 = [2015, 12, 31,11,4,101,0,3236.333333]
new_row_5 = [2015, 12, 31,12,4,101,0,3501.333333]
new_row_6 = [2015, 12, 31,13,4,101,0,3329.750000]
new_row_7 = [2015, 12, 31,14,4,101,0,3572.000000]
new_row_8 = [2015, 12, 31,15,4,101,0,3125.750000]

new_row_9 = [2015, 12, 31,18,4,101,0,3467.500000]
new_row_10 = [2015, 12, 31,19,4,101,0,3922.000000]
new_row_11 = [2015, 12, 31,20,4,101,0,2356.750000]
new_row_12 = [2015, 12, 31,21,4,101,0,1977.750000]

df_101.loc[len(df_101.index)] = new_row_0
df_101.loc[len(df_101.index)] = new_row_1
df_101.loc[len(df_101.index)] = new_row_2
df_101.loc[len(df_101.index)] = new_row_3
df_101.loc[len(df_101.index)] = new_row_4
df_101.loc[len(df_101.index)] = new_row_5
df_101.loc[len(df_101.index)] = new_row_6
df_101.loc[len(df_101.index)] = new_row_7
df_101.loc[len(df_101.index)] = new_row_8
df_101.loc[len(df_101.index)] = new_row_9
df_101.loc[len(df_101.index)] = new_row_10
df_101.loc[len(df_101.index)] = new_row_11
df_101.loc[len(df_101.index)] = new_row_12

df_sorted_101 = df_101.sort_values('horas')
#df_sorted_101
df_sorted_101_mean = df_sorted_101['media'].tolist()
df_sorted_101_mean
# Out:
# [729.0,
#  670.25,
#  435.75,
#  322.0,
#  246.33333333333331,
#  242.0,
#  854.45,
#  1365.75,
#  2274.6666666666665,
#  2700.0,
#  2924.75,
#  3236.333333,
#  3501.333333,
#  3329.75,
#  3572.0,
#  3125.75,
#  2910.333333333333,
#  3202.5,
#  3467.5,
#  3922.0,
#  2356.75,
#  1977.75,
#  647.3333333333334,
#  392.0]

# %%
df_dates_101 = dates_24.copy()
df_dates_101['Media'] = df_sorted_101_mean
df_dates_101.set_index('Fecha',inplace=True)
df_dates_101
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00   729.000000
# 2015-12-31 01:00:00   670.250000
# 2015-12-31 02:00:00   435.750000
# 2015-12-31 03:00:00   322.000000
# 2015-12-31 04:00:00   246.333333
# 2015-12-31 05:00:00   242.000000
# 2015-12-31 06:00:00   854.450000
# 2015-12-31 07:00:00  1365.750000
# 2015-12-31 08:00:00  2274.666667
# 2015-12-31 09:00:00  2700.000000
# 2015-12-31 10:00:00  2924.750000
# 2015-12-31 11:00:00  3236.333333
# 2015-12-31 12:00:00  3501.333333
# 2015-12-31 13:00:00  3329.750000
# 2015-12-31 14:00:00  3572.000000
# 2015-12-31 15:00:00  3125.750000
# 2015-12-31 16:00:00  2910.333333
# 2015-12-31 17:00:00  3202.500000
# 2015-12-31 18:00:00  3467.500000
# 2015-12-31 19:00:00  3922.000000
# 2015-12-31 20:00:00  2356.750000
# 2015-12-31 21:00:00  1977.750000
# 2015-12-31 22:00:00   647.333333
# 2015-12-31 23:00:00   392.000000

# %%
df_pred_dates_101 = pred_dates_24.copy()
df_pred_dates_101['Media'] = new_predictions_101
df_pred_dates_101.set_index('Fecha',inplace=True)
df_pred_dates_101
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00  1051.591702
# 2016-01-01 01:00:00   899.832518
# 2016-01-01 02:00:00   544.723482
# 2016-01-01 03:00:00   522.251622
# 2016-01-01 04:00:00   526.238912
# 2016-01-01 05:00:00   577.626450
# 2016-01-01 06:00:00   809.700010
# 2016-01-01 07:00:00  2004.120722
# 2016-01-01 08:00:00  1963.904279
# 2016-01-01 09:00:00  2032.339816
# 2016-01-01 10:00:00  2217.170133
# 2016-01-01 11:00:00  2342.865340
# 2016-01-01 12:00:00  2157.342527
# 2016-01-01 13:00:00  2187.144316
# 2016-01-01 14:00:00  2367.341099
# 2016-01-01 15:00:00  2562.086150
# 2016-01-01 16:00:00  2579.269934
# 2016-01-01 17:00:00  2595.125476
# 2016-01-01 18:00:00  2602.424050
# 2016-01-01 19:00:00  2572.809373
# 2016-01-01 20:00:00  2575.654249
# 2016-01-01 21:00:00  2575.654249
# 2016-01-01 22:00:00  2039.861580
# 2016-01-01 23:00:00   948.095548

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_dates_101, linestyle='solid', color='b')
plt.plot(df_pred_dates_101, linestyle='solid', color='r')

plt.legend(['2015','pred_101'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 101 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------**
# **-------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ***Tramo 1027 24 Horas***

# %%
df_predRF_1027 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_1027
# Out:
#        Actual   Predicción
# 4379   711.75   697.941400
# 393    987.75  1168.413192
# 1164  2671.25  2760.061539
# 4478   760.75   873.004632
# 731   2158.50  2111.815108
# ...       ...          ...
# 1652  2583.50  2586.925852
# 3291   795.00  2189.015813
# 3718   133.00   297.082982
# 1315  1082.50   488.823576
# 1945   843.75   967.586149
#
# [1489 rows x 2 columns]

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_1027 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_1027.csv',sep=';',engine='python')
dataML_pred_tramos_1027.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo     media-24
# 0  2016    1        1      0         5       1027        1  1724.454647
# 1  2016    1        1      1         5       1027        1  1725.208972
# 2  2016    1        1      2         5       1027        1  1730.701812
# 3  2016    1        1      3         5       1027        1  1733.267968
# 4  2016    1        1      4         5       1027        1  1740.431346

# %%
#Predicciones 24 Horas
new_predictions_1027 = modelo_rf.predict(dataML_pred_tramos_1027[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_1027
# Out:
# array([ 907.18099442,  844.35871849,  586.11256452,  508.78275912,
#         507.39191471,  516.27808019,  664.62607838, 1048.60798159,
#        1142.87969995, 1302.68979805, 1798.67879357, 2097.03799147,
#        2193.45636537, 2238.69539281, 2230.79339766, 2142.25763444,
#        2138.93189248, 2187.8884311 , 2631.14599743, 2633.675417  ,
#        2633.675417  , 2649.93418694, 1897.30583558, 1013.91442809])

# %%
#unimos las predicciones con las horas
data_pred_rf_1027 = pd.DataFrame(new_predictions_1027,columns = ['media'])
data_pred_rf_1027.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_1027)))
data_pred_rf_1027.set_index('Hora',inplace=True)


(data_pred_rf_1027
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 .set_caption('Predicciones 24H Av.Ausias March'))
# Out:
# <style  type="text/css" >
# #T_4baf8_row0_col0{
#             background-color:  #d7efd1;
#             color:  #000000;
#         }#T_4baf8_row1_col0{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_4baf8_row2_col0{
#             background-color:  #f2faef;
#             color:  #000000;
#         }#T_4baf8_row3_col0,#T_4baf8_row4_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_4baf8_row5_col0{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_4baf8_row6_col0{
#             background-color:  #edf8e9;
#             color:  #000000;
#         }#T_4baf8_row7_col0{
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }#T_4baf8_row8_col0{
#             background-color:  #bae3b3;
#             color:  #000000;
#         }#T_4baf8_row9_col0{
#             background-color:  #a2d99c;
#             color:  #000000;
#         }#T_4baf8_row10_col0{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }#T_4baf8_row11_col0{
#             background-color:  #258d47;
#             color:  #000000;
#         }#T_4baf8_row12_col0{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_4baf8_row13_col0{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_4baf8_row14_col0{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_4baf8_row15_col0{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_4baf8_row16_col0{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_4baf8_row17_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_4baf8_row18_col0{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_4baf8_row19_col0,#T_4baf8_row20_col0{
#             background-color:  #00451c;
#             color:  #f1f1f1;
#         }#T_4baf8_row21_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_4baf8_row22_col0{
#             background-color:  #3ba458;
#             color:  #000000;
#         }#T_4baf8_row23_col0{
#             background-color:  #cbeac4;
#             color:  #000000;
#         }</style><table id="T_4baf8_" ><caption>Predicciones 24H Av.Ausias March</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4baf8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4baf8_row0_col0" class="data row0 col0" >907.180994</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4baf8_row1_col0" class="data row1 col0" >844.358718</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4baf8_row2_col0" class="data row2 col0" >586.112565</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4baf8_row3_col0" class="data row3 col0" >508.782759</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4baf8_row4_col0" class="data row4 col0" >507.391915</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4baf8_row5_col0" class="data row5 col0" >516.278080</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4baf8_row6_col0" class="data row6 col0" >664.626078</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4baf8_row7_col0" class="data row7 col0" >1048.607982</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4baf8_row8_col0" class="data row8 col0" >1142.879700</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4baf8_row9_col0" class="data row9 col0" >1302.689798</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4baf8_row10_col0" class="data row10 col0" >1798.678794</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4baf8_row11_col0" class="data row11 col0" >2097.037991</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4baf8_row12_col0" class="data row12 col0" >2193.456365</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4baf8_row13_col0" class="data row13 col0" >2238.695393</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4baf8_row14_col0" class="data row14 col0" >2230.793398</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4baf8_row15_col0" class="data row15 col0" >2142.257634</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4baf8_row16_col0" class="data row16 col0" >2138.931892</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4baf8_row17_col0" class="data row17 col0" >2187.888431</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4baf8_row18_col0" class="data row18 col0" >2631.145997</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4baf8_row19_col0" class="data row19 col0" >2633.675417</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4baf8_row20_col0" class="data row20 col0" >2633.675417</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4baf8_row21_col0" class="data row21 col0" >2649.934187</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4baf8_row22_col0" class="data row22 col0" >1897.305836</td>
#             </tr>
#             <tr>
#                         <th id="T_4baf8_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4baf8_row23_col0" class="data row23 col0" >1013.914428</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_1027 = data_pred_rf_1027.mean()
print(media_RF_24_1027)

max_RF_24_1027 = data_pred_rf_1027.max()
print(max_RF_24_1027)

min_RF_24_1027 = data_pred_rf_1027.min()
print(min_RF_24_1027)
# Out:
# media    1604.845824
# dtype: float64
# media    2649.934187
# dtype: float64
# media    507.391915
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
sns.lineplot(data=data_pred_rf_1027).set(title='Predicciones 24 Horas Av. Ausias March')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Av. Ausias March')]

# %%
#Medias tramo 1027 31/12/2015
df_before_1027 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 1027)]

df_before_1027
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo        media
# 3001840  2015   12   31      1         4       1027        0   684.750000
# 3002241  2015   12   31      2         4       1027        0   409.000000
# 3002643  2015   12   31      4         4       1027        0   225.666667
# 3003044  2015   12   31      5         4       1027        0   265.000000
# 3003417  2015   12   31      8         4       1027        0  1837.000000
# 3003817  2015   12   31      9         4       1027        0  2108.000000
# 3004214  2015   12   31     10         4       1027        0  2583.500000
# 3004608  2015   12   31     11         4       1027        0  2896.500000
# 3005743  2015   12   31     15         4       1027        0  2667.000000
# 3006132  2015   12   31     16         4       1027        0  2334.000000
# 3006531  2015   12   31     17         4       1027        0  2345.000000
# 3006929  2015   12   31     18         4       1027        0  2483.000000
# 3007324  2015   12   31     22         4       1027        0   864.333333
# 3007726  2015   12   31     23         4       1027        0   534.000000

# %%
new_row_0 = [2015, 12, 31,0,4,1027,0,711.500000]
new_row_1 = [2015, 12, 31,3,4,1027,0,336.000000]
new_row_2 = [2015, 12, 31,6,4,1027,0,429.500000]
new_row_3 = [2015, 12, 31,7,4,1027,0,1002.750000]
new_row_4 = [2015, 12, 31,12,4,1027,0,3101.333333]
new_row_5 = [2015, 12, 31,13,4,1027,0,3458.750000]
new_row_6 = [2015, 12, 31,14,4,1027,0,3611.000000]
new_row_7 = [2015, 12, 31,19,4,1027,0,2729.000000]
new_row_8 = [2015, 12, 31,20,4,1027,0,2155.750000]
new_row_9 = [2015, 12, 31,21,4,1027,0,1533.750000]

df_before_1027.loc[len(df_before_1027.index)] = new_row_0
df_before_1027.loc[len(df_before_1027.index)] = new_row_1
df_before_1027.loc[len(df_before_1027.index)] = new_row_2
df_before_1027.loc[len(df_before_1027.index)] = new_row_3
df_before_1027.loc[len(df_before_1027.index)] = new_row_4
df_before_1027.loc[len(df_before_1027.index)] = new_row_5
df_before_1027.loc[len(df_before_1027.index)] = new_row_6
df_before_1027.loc[len(df_before_1027.index)] = new_row_7
df_before_1027.loc[len(df_before_1027.index)] = new_row_8
df_before_1027.loc[len(df_before_1027.index)] = new_row_9

df_sorted_1027 = df_before_1027.sort_values('horas')
df_sorted_1027_mean = df_sorted_1027['media'].tolist()
df_sorted_1027_mean
# Out:
# [711.5,
#  684.75,
#  409.0,
#  336.0,
#  225.66666666666663,
#  265.0,
#  429.5,
#  1002.75,
#  1837.0,
#  2108.0,
#  2583.5,
#  2896.5,
#  3101.333333,
#  3458.75,
#  3611.0,
#  2667.0,
#  2334.0,
#  2345.0,
#  2483.0,
#  2729.0,
#  2155.75,
#  1533.75,
#  864.3333333333334,
#  534.0]

# %%
df_dates_1027 = dates_24.copy()
df_dates_1027['Media'] = df_sorted_1027_mean
df_dates_1027.set_index('Fecha',inplace=True)
df_dates_1027
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00   711.500000
# 2015-12-31 01:00:00   684.750000
# 2015-12-31 02:00:00   409.000000
# 2015-12-31 03:00:00   336.000000
# 2015-12-31 04:00:00   225.666667
# 2015-12-31 05:00:00   265.000000
# 2015-12-31 06:00:00   429.500000
# 2015-12-31 07:00:00  1002.750000
# 2015-12-31 08:00:00  1837.000000
# 2015-12-31 09:00:00  2108.000000
# 2015-12-31 10:00:00  2583.500000
# 2015-12-31 11:00:00  2896.500000
# 2015-12-31 12:00:00  3101.333333
# 2015-12-31 13:00:00  3458.750000
# 2015-12-31 14:00:00  3611.000000
# 2015-12-31 15:00:00  2667.000000
# 2015-12-31 16:00:00  2334.000000
# 2015-12-31 17:00:00  2345.000000
# 2015-12-31 18:00:00  2483.000000
# 2015-12-31 19:00:00  2729.000000
# 2015-12-31 20:00:00  2155.750000
# 2015-12-31 21:00:00  1533.750000
# 2015-12-31 22:00:00   864.333333
# 2015-12-31 23:00:00   534.000000

# %%
df_pred_dates_1027 = pred_dates_24.copy()
df_pred_dates_1027['Media'] = new_predictions_1027
df_pred_dates_1027.set_index('Fecha',inplace=True)
df_pred_dates_1027
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00   907.180994
# 2016-01-01 01:00:00   844.358718
# 2016-01-01 02:00:00   586.112565
# 2016-01-01 03:00:00   508.782759
# 2016-01-01 04:00:00   507.391915
# 2016-01-01 05:00:00   516.278080
# 2016-01-01 06:00:00   664.626078
# 2016-01-01 07:00:00  1048.607982
# 2016-01-01 08:00:00  1142.879700
# 2016-01-01 09:00:00  1302.689798
# 2016-01-01 10:00:00  1798.678794
# 2016-01-01 11:00:00  2097.037991
# 2016-01-01 12:00:00  2193.456365
# 2016-01-01 13:00:00  2238.695393
# 2016-01-01 14:00:00  2230.793398
# 2016-01-01 15:00:00  2142.257634
# 2016-01-01 16:00:00  2138.931892
# 2016-01-01 17:00:00  2187.888431
# 2016-01-01 18:00:00  2631.145997
# 2016-01-01 19:00:00  2633.675417
# 2016-01-01 20:00:00  2633.675417
# 2016-01-01 21:00:00  2649.934187
# 2016-01-01 22:00:00  1897.305836
# 2016-01-01 23:00:00  1013.914428

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_dates_1027, linestyle='solid', color='b')
plt.plot(df_pred_dates_1027, linestyle='solid', color='r')

plt.legend(['2015','pred_1027'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 1027 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------**
# **-------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ***Tramo 1069 24 Horas***

# %%
df_predRF_1069 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_1069
# Out:
#            Actual   Predicción
# 5223  2460.666667  2326.098787
# 3053  1835.000000  2149.027199
# 5329   327.500000   401.197725
# 3698  1996.750000   334.943629
# 3973   116.500000   374.285571
# ...           ...          ...
# 307    306.250000   627.528848
# 4078  1703.500000  2320.600114
# 3312  1432.500000  1837.575728
# 6808   337.750000   402.487649
# 5508   670.750000   712.978736
#
# [2124 rows x 2 columns]

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_1069 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_1069.csv',sep=';',engine='python')
dataML_pred_tramos_1069.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo     media-24
# 0  2016    1        1      0         5       1069        1  1408.407756
# 1  2016    1        1      1         5       1069        1  1413.910801
# 2  2016    1        1      2         5       1069        1  1418.255455
# 3  2016    1        1      3         5       1069        1  1425.230036
# 4  2016    1        1      4         5       1069        1  1435.218507

# %%
#Predicciones 24 Horas
new_predictions_1069 = modelo_rf.predict(dataML_pred_tramos_1069[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_1069
# Out:
# array([ 693.9256545 ,  675.03445727,  347.59146084,  342.71823886,
#         341.55056043,  345.51486223,  654.04427688,  809.35197453,
#        1566.30771105, 1589.26511961, 1640.92748958, 1904.56360747,
#        1843.08656515, 1842.70422424, 1819.00123217, 1812.14132403,
#        1812.14132403, 1850.79018117, 1866.96596877, 1866.96596877,
#        1866.96596877, 1885.75045676, 1288.1154404 , 1148.99134722])

# %%
#unimos las predicciones con las horas
data_pred_rf_1069 = pd.DataFrame(new_predictions_1069,columns = ['media'])
data_pred_rf_1069.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_1069)))
data_pred_rf_1069.set_index('Hora',inplace=True)


(data_pred_rf_1069
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 .set_caption('Predicciones 24H Av.del Cid'))
# Out:
# <style  type="text/css" >
# #T_446d1_row0_col0{
#             background-color:  #cdecc7;
#             color:  #000000;
#         }#T_446d1_row1_col0{
#             background-color:  #d0edca;
#             color:  #000000;
#         }#T_446d1_row2_col0,#T_446d1_row3_col0,#T_446d1_row4_col0,#T_446d1_row5_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_446d1_row6_col0{
#             background-color:  #d3eecd;
#             color:  #000000;
#         }#T_446d1_row7_col0{
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }#T_446d1_row8_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_446d1_row9_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_446d1_row10_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_446d1_row11_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_446d1_row12_col0,#T_446d1_row13_col0{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_446d1_row14_col0{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_446d1_row15_col0,#T_446d1_row16_col0{
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }#T_446d1_row17_col0{
#             background-color:  #004e1f;
#             color:  #f1f1f1;
#         }#T_446d1_row18_col0,#T_446d1_row19_col0,#T_446d1_row20_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_446d1_row21_col0{
#             background-color:  #00481d;
#             color:  #f1f1f1;
#         }#T_446d1_row22_col0{
#             background-color:  #48ae60;
#             color:  #000000;
#         }#T_446d1_row23_col0{
#             background-color:  #6dc072;
#             color:  #000000;
#         }</style><table id="T_446d1_" ><caption>Predicciones 24H Av.del Cid</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_446d1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_446d1_row0_col0" class="data row0 col0" >693.925655</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_446d1_row1_col0" class="data row1 col0" >675.034457</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_446d1_row2_col0" class="data row2 col0" >347.591461</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_446d1_row3_col0" class="data row3 col0" >342.718239</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_446d1_row4_col0" class="data row4 col0" >341.550560</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_446d1_row5_col0" class="data row5 col0" >345.514862</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_446d1_row6_col0" class="data row6 col0" >654.044277</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_446d1_row7_col0" class="data row7 col0" >809.351975</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_446d1_row8_col0" class="data row8 col0" >1566.307711</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_446d1_row9_col0" class="data row9 col0" >1589.265120</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_446d1_row10_col0" class="data row10 col0" >1640.927490</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_446d1_row11_col0" class="data row11 col0" >1904.563607</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_446d1_row12_col0" class="data row12 col0" >1843.086565</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_446d1_row13_col0" class="data row13 col0" >1842.704224</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_446d1_row14_col0" class="data row14 col0" >1819.001232</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_446d1_row15_col0" class="data row15 col0" >1812.141324</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_446d1_row16_col0" class="data row16 col0" >1812.141324</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_446d1_row17_col0" class="data row17 col0" >1850.790181</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_446d1_row18_col0" class="data row18 col0" >1866.965969</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_446d1_row19_col0" class="data row19 col0" >1866.965969</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_446d1_row20_col0" class="data row20 col0" >1866.965969</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_446d1_row21_col0" class="data row21 col0" >1885.750457</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_446d1_row22_col0" class="data row22 col0" >1288.115440</td>
#             </tr>
#             <tr>
#                         <th id="T_446d1_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_446d1_row23_col0" class="data row23 col0" >1148.991347</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_1069 = data_pred_rf_1069.mean()
print(media_RF_24_1069)

max_RF_24_1069 = data_pred_rf_1069.max()
print(max_RF_24_1069)

min_RF_24_1069 = data_pred_rf_1069.min()
print(min_RF_24_1069)
# Out:
# media    1325.600642
# dtype: float64
# media    1904.563607
# dtype: float64
# media    341.55056
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
sns.lineplot(data=data_pred_rf_1069).set(title='Predicciones 24 Horas Av. del Cid')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Av. del Cid')]

# %%
#Medias tramo 1069 31/12/2015
df_before_1069 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 1069)]
df_before_1069
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo        media
# 3001875  2015   12   31      1         4       1069        0   578.500000
# 3002276  2015   12   31      2         4       1069        0   290.500000
# 3002678  2015   12   31      4         4       1069        0   151.666667
# 3003078  2015   12   31      5         4       1069        0   169.000000
# 3003452  2015   12   31      8         4       1069        0  1755.666667
# 3003852  2015   12   31      9         4       1069        0  1907.000000
# 3004248  2015   12   31     10         4       1069        0  2368.750000
# 3004640  2015   12   31     11         4       1069        0  2432.750000
# 3005028  2015   12   31     12         4       1069        0  2801.750000
# 3005403  2015   12   31     13         4       1069        0  2905.000000
# 3005776  2015   12   31     15         4       1069        0  2101.250000
# 3006167  2015   12   31     16         4       1069        0  1692.333333
# 3006566  2015   12   31     17         4       1069        0  1711.500000
# 3006963  2015   12   31     18         4       1069        0  1728.000000
# 3007359  2015   12   31     22         4       1069        0   686.333333
# 3007761  2015   12   31     23         4       1069        0   524.000000

# %%
new_row_0 = [2015, 12, 31,0,4,1069,0,643.500000]
new_row_1 = [2015, 12, 31,3,4,1069,0,224.000000]
new_row_2 = [2015, 12, 31,6,4,1069,0,335.500000]
new_row_3 = [2015, 12, 31,7,4,1069,0,993.750000]
new_row_4 = [2015, 12, 31,14,4,1069,0,2587.000000]
new_row_5 = [2015, 12, 31,19,4,1069,0,2123.000000]
new_row_6 = [2015, 12, 31,20,4,1069,0,1748.750000]
new_row_7 = [2015, 12, 31,21,4,1069,0,1273.000000]

df_before_1069.loc[len(df_before_1069.index)] = new_row_0
df_before_1069.loc[len(df_before_1069.index)] = new_row_1
df_before_1069.loc[len(df_before_1069.index)] = new_row_2
df_before_1069.loc[len(df_before_1069.index)] = new_row_3
df_before_1069.loc[len(df_before_1069.index)] = new_row_4
df_before_1069.loc[len(df_before_1069.index)] = new_row_5
df_before_1069.loc[len(df_before_1069.index)] = new_row_6
df_before_1069.loc[len(df_before_1069.index)] = new_row_7

df_sorted_1069 = df_before_1069.sort_values('horas')
df_sorted_1069_mean = df_sorted_1069['media'].tolist()
df_sorted_1069_mean
# Out:
# [643.5,
#  578.5,
#  290.5,
#  224.0,
#  151.66666666666666,
#  169.0,
#  335.5,
#  993.75,
#  1755.6666666666667,
#  1907.0,
#  2368.75,
#  2432.75,
#  2801.75,
#  2905.0,
#  2587.0,
#  2101.25,
#  1692.3333333333333,
#  1711.5,
#  1728.0,
#  2123.0,
#  1748.75,
#  1273.0,
#  686.3333333333334,
#  524.0]

# %%
df_dates_1069 = dates_24.copy()
df_dates_1069['Media'] = df_sorted_1069_mean
df_dates_1069.set_index('Fecha',inplace=True)
df_dates_1069
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00   643.500000
# 2015-12-31 01:00:00   578.500000
# 2015-12-31 02:00:00   290.500000
# 2015-12-31 03:00:00   224.000000
# 2015-12-31 04:00:00   151.666667
# 2015-12-31 05:00:00   169.000000
# 2015-12-31 06:00:00   335.500000
# 2015-12-31 07:00:00   993.750000
# 2015-12-31 08:00:00  1755.666667
# 2015-12-31 09:00:00  1907.000000
# 2015-12-31 10:00:00  2368.750000
# 2015-12-31 11:00:00  2432.750000
# 2015-12-31 12:00:00  2801.750000
# 2015-12-31 13:00:00  2905.000000
# 2015-12-31 14:00:00  2587.000000
# 2015-12-31 15:00:00  2101.250000
# 2015-12-31 16:00:00  1692.333333
# 2015-12-31 17:00:00  1711.500000
# 2015-12-31 18:00:00  1728.000000
# 2015-12-31 19:00:00  2123.000000
# 2015-12-31 20:00:00  1748.750000
# 2015-12-31 21:00:00  1273.000000
# 2015-12-31 22:00:00   686.333333
# 2015-12-31 23:00:00   524.000000

# %%
df_pred_dates_1069 = pred_dates_24.copy()
df_pred_dates_1069['Media'] = new_predictions_1069
df_pred_dates_1069.set_index('Fecha',inplace=True)
df_pred_dates_1069
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00   693.925655
# 2016-01-01 01:00:00   675.034457
# 2016-01-01 02:00:00   347.591461
# 2016-01-01 03:00:00   342.718239
# 2016-01-01 04:00:00   341.550560
# 2016-01-01 05:00:00   345.514862
# 2016-01-01 06:00:00   654.044277
# 2016-01-01 07:00:00   809.351975
# 2016-01-01 08:00:00  1566.307711
# 2016-01-01 09:00:00  1589.265120
# 2016-01-01 10:00:00  1640.927490
# 2016-01-01 11:00:00  1904.563607
# 2016-01-01 12:00:00  1843.086565
# 2016-01-01 13:00:00  1842.704224
# 2016-01-01 14:00:00  1819.001232
# 2016-01-01 15:00:00  1812.141324
# 2016-01-01 16:00:00  1812.141324
# 2016-01-01 17:00:00  1850.790181
# 2016-01-01 18:00:00  1866.965969
# 2016-01-01 19:00:00  1866.965969
# 2016-01-01 20:00:00  1866.965969
# 2016-01-01 21:00:00  1885.750457
# 2016-01-01 22:00:00  1288.115440
# 2016-01-01 23:00:00  1148.991347

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_dates_1069, linestyle='solid', color='b')
plt.plot(df_pred_dates_1069, linestyle='solid', color='r')

plt.legend(['2015','pred_1069'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 1069 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------**
# **-------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ***Predicciones Tramos 1082 24 Horas***

# %%
df_predRF_1082 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_1082
# Out:
#            Actual   Predicción
# 2447   141.333333   417.454712
# 3712   136.000000   199.780258
# 1964  2266.750000  1388.685451
# 2554  2882.250000  2470.184195
# 1694  1783.000000  1867.938272
# ...           ...          ...
# 460   1272.000000  1480.137285
# 1067  1272.000000   923.341202
# 87    2339.666667  2674.744689
# 282    129.666667   233.230005
# 1221   323.000000   429.966341
#
# [1148 rows x 2 columns]

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_1082 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_1082.csv',sep=';',engine='python')
dataML_pred_tramos_1082.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo     media-24
# 0  2016    1        1      0         5       1082        1  1956.696760
# 1  2016    1        1      1         5       1082        1  1979.460593
# 2  2016    1        1      2         5       1082        1  1976.487413
# 3  2016    1        1      3         5       1082        1  1973.845288
# 4  2016    1        1      4         5       1082        1  1978.133326

# %%
#Predicciones 24 Horas
new_predictions_1082 = modelo_rf.predict(dataML_pred_tramos_1082[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_1082
# Out:
# array([1558.99156673, 1690.05920331, 1233.95759808, 1082.04538338,
#        1037.19670987, 1042.5435563 ,  906.30526006, 1477.30116175,
#        1377.80053845, 1619.22627727, 2119.20716209, 2468.74591799,
#        2507.7860842 , 2498.14613976, 2477.64214365, 2406.74781597,
#        2351.07959178, 2341.98368748, 2453.89788673, 2467.08641336,
#        2470.71558003, 2475.30600063, 2520.87023601, 1350.56264631])

# %%
#unimos las predicciones con las horas
data_pred_rf_1082 = pd.DataFrame(new_predictions_1082,columns = ['media'])
data_pred_rf_1082.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_1082)))
data_pred_rf_1082.set_index('Hora',inplace=True)


(data_pred_rf_1082
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 .set_caption('Predicciones 24H  Av.Cortes Valencianas'))
# Out:
# <style  type="text/css" >
# #T_101d2_row0_col0{
#             background-color:  #97d492;
#             color:  #000000;
#         }#T_101d2_row1_col0{
#             background-color:  #79c67a;
#             color:  #000000;
#         }#T_101d2_row2_col0{
#             background-color:  #d3eecd;
#             color:  #000000;
#         }#T_101d2_row3_col0{
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }#T_101d2_row4_col0{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_101d2_row5_col0{
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }#T_101d2_row6_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_101d2_row7_col0{
#             background-color:  #a8dca2;
#             color:  #000000;
#         }#T_101d2_row8_col0{
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }#T_101d2_row9_col0{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_101d2_row10_col0{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_101d2_row11_col0,#T_101d2_row19_col0{
#             background-color:  #004e1f;
#             color:  #f1f1f1;
#         }#T_101d2_row12_col0{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_101d2_row13_col0{
#             background-color:  #00481d;
#             color:  #f1f1f1;
#         }#T_101d2_row14_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_101d2_row15_col0{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_101d2_row16_col0{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_101d2_row17_col0{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_101d2_row18_col0{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_101d2_row20_col0,#T_101d2_row21_col0{
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }#T_101d2_row22_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_101d2_row23_col0{
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }</style><table id="T_101d2_" ><caption>Predicciones 24H  Av.Cortes Valencianas</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_101d2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_101d2_row0_col0" class="data row0 col0" >1558.991567</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_101d2_row1_col0" class="data row1 col0" >1690.059203</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_101d2_row2_col0" class="data row2 col0" >1233.957598</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_101d2_row3_col0" class="data row3 col0" >1082.045383</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_101d2_row4_col0" class="data row4 col0" >1037.196710</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_101d2_row5_col0" class="data row5 col0" >1042.543556</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_101d2_row6_col0" class="data row6 col0" >906.305260</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_101d2_row7_col0" class="data row7 col0" >1477.301162</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_101d2_row8_col0" class="data row8 col0" >1377.800538</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_101d2_row9_col0" class="data row9 col0" >1619.226277</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_101d2_row10_col0" class="data row10 col0" >2119.207162</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_101d2_row11_col0" class="data row11 col0" >2468.745918</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_101d2_row12_col0" class="data row12 col0" >2507.786084</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_101d2_row13_col0" class="data row13 col0" >2498.146140</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_101d2_row14_col0" class="data row14 col0" >2477.642144</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_101d2_row15_col0" class="data row15 col0" >2406.747816</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_101d2_row16_col0" class="data row16 col0" >2351.079592</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_101d2_row17_col0" class="data row17 col0" >2341.983687</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_101d2_row18_col0" class="data row18 col0" >2453.897887</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_101d2_row19_col0" class="data row19 col0" >2467.086413</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_101d2_row20_col0" class="data row20 col0" >2470.715580</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_101d2_row21_col0" class="data row21 col0" >2475.306001</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_101d2_row22_col0" class="data row22 col0" >2520.870236</td>
#             </tr>
#             <tr>
#                         <th id="T_101d2_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_101d2_row23_col0" class="data row23 col0" >1350.562646</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_1082 = data_pred_rf_1082.mean()
print(media_RF_24_1082)

max_RF_24_1082 = data_pred_rf_1082.max()
print(max_RF_24_1082)

min_RF_24_1082 = data_pred_rf_1082.min()
print(min_RF_24_1082)
# Out:
# media    1913.966857
# dtype: float64
# media    2520.870236
# dtype: float64
# media    906.30526
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
sns.lineplot(data=data_pred_rf_1082).set(title='Predicciones 24 Horas Av. Cortes Valencianas')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Av. Cortes Valencianas')]

# %%
#Medias tramo 1082 31/12/2015
df_before_1082 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 1082)]
df_before_1082
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo        media
# 3001886  2015   12   31      1         4       1082        0  1028.250000
# 3002287  2015   12   31      2         4       1082        0   604.500000
# 3002689  2015   12   31      4         4       1082        0   255.000000
# 3003089  2015   12   31      5         4       1082        0   176.000000
# 3003462  2015   12   31      8         4       1082        0  2356.666667
# 3003862  2015   12   31      9         4       1082        0  2942.000000
# 3006177  2015   12   31     16         4       1082        0  3101.666667
# 3006576  2015   12   31     17         4       1082        0  3238.000000
# 3007370  2015   12   31     22         4       1082        0  1024.333333
# 3007772  2015   12   31     23         4       1082        0   646.000000

# %%
new_row_0 = [2015, 12, 31,0,4,1082,0,1173.500000]
new_row_1 = [2015, 12, 31,3,4,1082,0,429.000000]
new_row_2 = [2015, 12, 31,6,4,1082,0,335.500000]
new_row_3 = [2015, 12, 31,7,4,1082,0,1127.750000]
new_row_4 = [2015, 12, 31,10,4,1082,0,3258.000000]
new_row_5 = [2015, 12, 31,11,4,1082,0,3567.000000]
new_row_6 = [2015, 12, 31,12,4,1082,0,2932.750000]
new_row_7 = [2015, 12, 31,13,4,1082,0,3076.000000]
new_row_8 = [2015, 12, 31,14,4,1082,0,3239.000000]
new_row_9 = [2015, 12, 31,15,4,1082,0,2715.500000]
new_row_10 = [2015, 12, 31,18,4,1082,0,3345.000000]
new_row_11 = [2015, 12, 31,19,4,1082,0,2892.000000]
new_row_12 = [2015, 12, 31,20,4,1082,0,1934.500000]
new_row_13 = [2015, 12, 31,21,4,1082,0,1297.500000]

df_before_1082.loc[len(df_before_1082.index)] = new_row_0
df_before_1082.loc[len(df_before_1082.index)] = new_row_1
df_before_1082.loc[len(df_before_1082.index)] = new_row_2
df_before_1082.loc[len(df_before_1082.index)] = new_row_3
df_before_1082.loc[len(df_before_1082.index)] = new_row_4
df_before_1082.loc[len(df_before_1082.index)] = new_row_5
df_before_1082.loc[len(df_before_1082.index)] = new_row_6
df_before_1082.loc[len(df_before_1082.index)] = new_row_7
df_before_1082.loc[len(df_before_1082.index)] = new_row_8
df_before_1082.loc[len(df_before_1082.index)] = new_row_9
df_before_1082.loc[len(df_before_1082.index)] = new_row_10
df_before_1082.loc[len(df_before_1082.index)] = new_row_11
df_before_1082.loc[len(df_before_1082.index)] = new_row_12
df_before_1082.loc[len(df_before_1082.index)] = new_row_13

df_sorted_1082 = df_before_1082.sort_values('horas')
df_sorted_1082_mean = df_sorted_1082['media'].tolist()
df_sorted_1082_mean
# Out:
# [1173.5,
#  1028.25,
#  604.5,
#  429.0,
#  255.0,
#  176.0,
#  335.5,
#  1127.75,
#  2356.6666666666665,
#  2942.0,
#  3258.0,
#  3567.0,
#  2932.75,
#  3076.0,
#  3239.0,
#  2715.5,
#  3101.6666666666665,
#  3238.0,
#  3345.0,
#  2892.0,
#  1934.5,
#  1297.5,
#  1024.3333333333333,
#  646.0]

# %%
df_dates_1082 = dates_24.copy()
df_dates_1082['Media'] = df_sorted_1082_mean
df_dates_1082.set_index('Fecha',inplace=True)
df_dates_1082
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00  1173.500000
# 2015-12-31 01:00:00  1028.250000
# 2015-12-31 02:00:00   604.500000
# 2015-12-31 03:00:00   429.000000
# 2015-12-31 04:00:00   255.000000
# 2015-12-31 05:00:00   176.000000
# 2015-12-31 06:00:00   335.500000
# 2015-12-31 07:00:00  1127.750000
# 2015-12-31 08:00:00  2356.666667
# 2015-12-31 09:00:00  2942.000000
# 2015-12-31 10:00:00  3258.000000
# 2015-12-31 11:00:00  3567.000000
# 2015-12-31 12:00:00  2932.750000
# 2015-12-31 13:00:00  3076.000000
# 2015-12-31 14:00:00  3239.000000
# 2015-12-31 15:00:00  2715.500000
# 2015-12-31 16:00:00  3101.666667
# 2015-12-31 17:00:00  3238.000000
# 2015-12-31 18:00:00  3345.000000
# 2015-12-31 19:00:00  2892.000000
# 2015-12-31 20:00:00  1934.500000
# 2015-12-31 21:00:00  1297.500000
# 2015-12-31 22:00:00  1024.333333
# 2015-12-31 23:00:00   646.000000

# %%
df_pred_dates_1082 = pred_dates_24.copy()
df_pred_dates_1082['Media'] = new_predictions_1082
df_pred_dates_1082.set_index('Fecha',inplace=True)
df_pred_dates_1082
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00  1558.991567
# 2016-01-01 01:00:00  1690.059203
# 2016-01-01 02:00:00  1233.957598
# 2016-01-01 03:00:00  1082.045383
# 2016-01-01 04:00:00  1037.196710
# 2016-01-01 05:00:00  1042.543556
# 2016-01-01 06:00:00   906.305260
# 2016-01-01 07:00:00  1477.301162
# 2016-01-01 08:00:00  1377.800538
# 2016-01-01 09:00:00  1619.226277
# 2016-01-01 10:00:00  2119.207162
# 2016-01-01 11:00:00  2468.745918
# 2016-01-01 12:00:00  2507.786084
# 2016-01-01 13:00:00  2498.146140
# 2016-01-01 14:00:00  2477.642144
# 2016-01-01 15:00:00  2406.747816
# 2016-01-01 16:00:00  2351.079592
# 2016-01-01 17:00:00  2341.983687
# 2016-01-01 18:00:00  2453.897887
# 2016-01-01 19:00:00  2467.086413
# 2016-01-01 20:00:00  2470.715580
# 2016-01-01 21:00:00  2475.306001
# 2016-01-01 22:00:00  2520.870236
# 2016-01-01 23:00:00  1350.562646

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_dates_1082, linestyle='solid', color='b')
plt.plot(df_pred_dates_1082, linestyle='solid', color='r')

plt.legend(['2015','pred_1082'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 1082 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------**
# **-------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ***Predicciones Tramo 10357 24 Horas***

# %%
df_predRF_10357 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_10357
# Out:
#            Actual   Predicción
# 2389   260.000000   386.292688
# 3034   318.333333   330.106929
# 6000  2458.250000  2075.121190
# 5351   806.666667  1025.927762
# 5477  2902.000000  2413.073389
# ...           ...          ...
# 2117  2550.250000  2383.957281
# 4017  1163.000000   435.336696
# 5839  2355.000000  2059.230379
# 4617  2736.000000  2378.866082
# 3149  2268.000000  2118.212764
#
# [2308 rows x 2 columns]

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_10357 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_10357.csv',sep=';',engine='python')
dataML_pred_tramos_10357.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo     media-24
# 0  2016    1        1      0         5      10357        1  1032.697234
# 1  2016    1        1      1         5      10357        1  1067.171938
# 2  2016    1        1      2         5      10357        1  1082.865431
# 3  2016    1        1      3         5      10357        1  1095.412680
# 4  2016    1        1      4         5      10357        1  1110.390485

# %%
#Predicciones 24 Horas
new_predictions_10357 = modelo_rf.predict(dataML_pred_tramos_10357[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_10357
# Out:
# array([1186.27673894, 1227.30423561,  591.34497173,  484.1418128 ,
#         484.1418128 ,  486.05382264,  501.86235075,  602.38122151,
#        1084.43081428, 1053.53928776, 1435.1007476 , 1483.9428678 ,
#        1840.48817017, 1857.79408896, 1851.77399817, 1831.99984572,
#        1792.44223936, 1933.88141481, 2014.05794098, 2024.63499844,
#        2056.8638624 , 1711.40979191,  918.55731111,  562.15355462])

# %%
#unimos las predicciones con las horas
data_pred_rf_10357 = pd.DataFrame(new_predictions_10357,columns = ['media'])
data_pred_rf_10357.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_10357)))
data_pred_rf_10357.set_index('Hora',inplace=True)

#background_gradient: https://matplotlib.org/stable/tutorials/colors/colormaps.html

(data_pred_rf_10357
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 .set_caption('Predicciones 24H  Plaza Ayuntamiento'))
# Out:
# <style  type="text/css" >
# #T_ff886_row0_col0{
#             background-color:  #87cd86;
#             color:  #000000;
#         }#T_ff886_row1_col0{
#             background-color:  #7fc97f;
#             color:  #000000;
#         }#T_ff886_row2_col0{
#             background-color:  #edf8ea;
#             color:  #000000;
#         }#T_ff886_row3_col0,#T_ff886_row4_col0,#T_ff886_row5_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_ff886_row6_col0{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_ff886_row7_col0{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_ff886_row8_col0{
#             background-color:  #9fd899;
#             color:  #000000;
#         }#T_ff886_row9_col0{
#             background-color:  #a5db9f;
#             color:  #000000;
#         }#T_ff886_row10_col0{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }#T_ff886_row11_col0{
#             background-color:  #3fa85b;
#             color:  #000000;
#         }#T_ff886_row12_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_ff886_row13_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_ff886_row14_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_ff886_row15_col0{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_ff886_row16_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_ff886_row17_col0{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_ff886_row18_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_ff886_row19_col0{
#             background-color:  #004a1e;
#             color:  #f1f1f1;
#         }#T_ff886_row20_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_ff886_row21_col0{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_ff886_row22_col0{
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }#T_ff886_row23_col0{
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }</style><table id="T_ff886_" ><caption>Predicciones 24H  Plaza Ayuntamiento</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff886_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ff886_row0_col0" class="data row0 col0" >1186.276739</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ff886_row1_col0" class="data row1 col0" >1227.304236</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ff886_row2_col0" class="data row2 col0" >591.344972</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ff886_row3_col0" class="data row3 col0" >484.141813</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ff886_row4_col0" class="data row4 col0" >484.141813</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ff886_row5_col0" class="data row5 col0" >486.053823</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ff886_row6_col0" class="data row6 col0" >501.862351</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ff886_row7_col0" class="data row7 col0" >602.381222</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ff886_row8_col0" class="data row8 col0" >1084.430814</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ff886_row9_col0" class="data row9 col0" >1053.539288</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ff886_row10_col0" class="data row10 col0" >1435.100748</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ff886_row11_col0" class="data row11 col0" >1483.942868</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ff886_row12_col0" class="data row12 col0" >1840.488170</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ff886_row13_col0" class="data row13 col0" >1857.794089</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ff886_row14_col0" class="data row14 col0" >1851.773998</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_ff886_row15_col0" class="data row15 col0" >1831.999846</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_ff886_row16_col0" class="data row16 col0" >1792.442239</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_ff886_row17_col0" class="data row17 col0" >1933.881415</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_ff886_row18_col0" class="data row18 col0" >2014.057941</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_ff886_row19_col0" class="data row19 col0" >2024.634998</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_ff886_row20_col0" class="data row20 col0" >2056.863862</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_ff886_row21_col0" class="data row21 col0" >1711.409792</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_ff886_row22_col0" class="data row22 col0" >918.557311</td>
#             </tr>
#             <tr>
#                         <th id="T_ff886_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_ff886_row23_col0" class="data row23 col0" >562.153555</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_10357 = data_pred_rf_10357.mean()
print(media_RF_24_10357)

max_RF_24_10357 = data_pred_rf_10357.max()
print(max_RF_24_10357)

min_RF_24_10357 = data_pred_rf_10357.min()
print(min_RF_24_10357)
# Out:
# media    1292.357413
# dtype: float64
# media    2056.863862
# dtype: float64
# media    484.141813
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
sns.lineplot(data=data_pred_rf_10357).set(title='Predicciones 24 Horas Plz. Ayuntamiento')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Plz. Ayuntamiento')]

# %%
#Medias tramo 10357 31/12/2015
df_before_10357 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 10357)]
df_before_10357
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo        media
# 3002153  2015   12   31      1         4      10357        0   369.750000
# 3002554  2015   12   31      2         4      10357        0   224.750000
# 3002955  2015   12   31      4         4      10357        0   142.666667
# 3003333  2015   12   31      5         4      10357        0   155.000000
# 3003729  2015   12   31      8         4      10357        0  1025.000000
# 3004127  2015   12   31      9         4      10357        0  1141.000000
# 3004522  2015   12   31     10         4      10357        0  1379.000000
# 3004912  2015   12   31     11         4      10357        0  1650.000000
# 3005290  2015   12   31     12         4      10357        0  2021.000000
# 3005661  2015   12   31     13         4      10357        0  2232.000000
# 3006046  2015   12   31     15         4      10357        0  1765.000000
# 3006443  2015   12   31     16         4      10357        0  1470.000000
# 3006842  2015   12   31     17         4      10357        0  1400.250000
# 3007237  2015   12   31     18         4      10357        0  1511.000000
# 3007637  2015   12   31     22         4      10357        0   473.000000
# 3008031  2015   12   31     23         4      10357        0   393.000000

# %%
new_row_0 = [2015, 12, 31,0,4,1082,0,476.500000]
new_row_1 = [2015, 12, 31,3,4,1082,0,201.000000]
new_row_2 = [2015, 12, 31,6,4,1082,0,333.500000]
new_row_3 = [2015, 12, 31,7,4,1082,0,825.750000]
new_row_4 = [2015, 12, 31,14,4,1082,0,2147.000000]
new_row_5 = [2015, 12, 31,19,4,1082,0,1239.000000]
new_row_6 = [2015, 12, 31,20,4,1082,0,976.750000]
new_row_7 = [2015, 12, 31,21,4,1082,0,534.000000]


df_before_10357.loc[len(df_before_10357.index)] = new_row_0
df_before_10357.loc[len(df_before_10357.index)] = new_row_1
df_before_10357.loc[len(df_before_10357.index)] = new_row_2
df_before_10357.loc[len(df_before_10357.index)] = new_row_3
df_before_10357.loc[len(df_before_10357.index)] = new_row_4
df_before_10357.loc[len(df_before_10357.index)] = new_row_5
df_before_10357.loc[len(df_before_10357.index)] = new_row_6
df_before_10357.loc[len(df_before_10357.index)] = new_row_7

df_sorted_10357= df_before_10357.sort_values('horas')
df_sorted_10357_mean = df_sorted_10357['media'].tolist()
df_sorted_10357_mean
# Out:
# [476.5,
#  369.75,
#  224.75,
#  201.0,
#  142.66666666666666,
#  155.0,
#  333.5,
#  825.75,
#  1025.0,
#  1141.0,
#  1379.0,
#  1650.0,
#  2021.0,
#  2232.0,
#  2147.0,
#  1765.0,
#  1470.0,
#  1400.25,
#  1511.0,
#  1239.0,
#  976.75,
#  534.0,
#  473.0,
#  393.0]

# %%
df_dates_10357 = dates_24.copy()
df_dates_10357['Media'] = df_sorted_10357_mean
df_dates_10357.set_index('Fecha',inplace=True)
df_dates_10357
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00   476.500000
# 2015-12-31 01:00:00   369.750000
# 2015-12-31 02:00:00   224.750000
# 2015-12-31 03:00:00   201.000000
# 2015-12-31 04:00:00   142.666667
# 2015-12-31 05:00:00   155.000000
# 2015-12-31 06:00:00   333.500000
# 2015-12-31 07:00:00   825.750000
# 2015-12-31 08:00:00  1025.000000
# 2015-12-31 09:00:00  1141.000000
# 2015-12-31 10:00:00  1379.000000
# 2015-12-31 11:00:00  1650.000000
# 2015-12-31 12:00:00  2021.000000
# 2015-12-31 13:00:00  2232.000000
# 2015-12-31 14:00:00  2147.000000
# 2015-12-31 15:00:00  1765.000000
# 2015-12-31 16:00:00  1470.000000
# 2015-12-31 17:00:00  1400.250000
# 2015-12-31 18:00:00  1511.000000
# 2015-12-31 19:00:00  1239.000000
# 2015-12-31 20:00:00   976.750000
# 2015-12-31 21:00:00   534.000000
# 2015-12-31 22:00:00   473.000000
# 2015-12-31 23:00:00   393.000000

# %%
df_pred_dates_10357 = pred_dates_24.copy()
df_pred_dates_10357['Media'] = new_predictions_10357
df_pred_dates_10357.set_index('Fecha',inplace=True)
df_pred_dates_10357
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00  1186.276739
# 2016-01-01 01:00:00  1227.304236
# 2016-01-01 02:00:00   591.344972
# 2016-01-01 03:00:00   484.141813
# 2016-01-01 04:00:00   484.141813
# 2016-01-01 05:00:00   486.053823
# 2016-01-01 06:00:00   501.862351
# 2016-01-01 07:00:00   602.381222
# 2016-01-01 08:00:00  1084.430814
# 2016-01-01 09:00:00  1053.539288
# 2016-01-01 10:00:00  1435.100748
# 2016-01-01 11:00:00  1483.942868
# 2016-01-01 12:00:00  1840.488170
# 2016-01-01 13:00:00  1857.794089
# 2016-01-01 14:00:00  1851.773998
# 2016-01-01 15:00:00  1831.999846
# 2016-01-01 16:00:00  1792.442239
# 2016-01-01 17:00:00  1933.881415
# 2016-01-01 18:00:00  2014.057941
# 2016-01-01 19:00:00  2024.634998
# 2016-01-01 20:00:00  2056.863862
# 2016-01-01 21:00:00  1711.409792
# 2016-01-01 22:00:00   918.557311
# 2016-01-01 23:00:00   562.153555

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_dates_10357, linestyle='solid', color='b')
plt.plot(df_pred_dates_10357, linestyle='solid', color='r')

plt.legend(['2015','pred_10357'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 10357 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# ***Tramo 107 24 Horas***

# %%
df_predRF_107 = pd.DataFrame({'Actual': y_test, 'Predicción': pred_rf})
df_predRF_107
# Out:
#            Actual   Predicción
# 2389  2091.250000  1991.355474
# 3034  2658.750000  2543.889162
# 6000  2013.000000  2001.699748
# 5351  2912.000000  2312.076840
# 5477  2904.500000  2277.905556
# ...           ...          ...
# 2117  2522.000000  2360.783239
# 4017  1454.000000  1559.986000
# 5839  2268.000000  1934.671157
# 4617   177.666667   624.137793
# 3149  2401.750000  1980.402619
#
# [2308 rows x 2 columns]

# %%
#Cargamos dataset preparado de predecciones
dataML_pred_tramos_107 = pd.read_csv('/../TFM/Machine_Learning_Data/predictions/pred_data_sections_rolling_24_107.csv',sep=';',engine='python')
dataML_pred_tramos_107.head(5)
# Out:
#     año  mes  dia_mes  horas  dias_sem  id_tramos  festivo    media-24
# 0  2016    1        1      0         5        107        1  696.892912
# 1  2016    1        1      1         5        107        1  704.849240
# 2  2016    1        1      2         5        107        1  704.415127
# 3  2016    1        1      3         5        107        1  708.614903
# 4  2016    1        1      4         5        107        1  714.689680

# %%
#Predicciones 24 Horas
new_predictions_107 = modelo_rf.predict(dataML_pred_tramos_107[['mes','dia_mes','horas','dias_sem','festivo','media-24']])
new_predictions_107
# Out:
# array([ 486.25732455,  443.68829445,  320.4776916 ,  297.80695872,
#         297.80695872,  294.37253279,  347.50149561,  653.40321888,
#        1195.18618702, 1185.24137094, 1142.61666462, 1052.02349205,
#        1144.64111397, 1261.78447802, 1257.41139805, 1311.04377305,
#        1319.8498919 , 1402.6724905 , 1398.7827524 , 1338.41785657,
#        1329.63774433, 1314.75792141,  754.41385988,  450.80560666])

# %%
#unimos las predicciones con las horas
data_pred_rf_107 = pd.DataFrame(new_predictions_107,columns = ['media'])
data_pred_rf_107.insert(loc=0, column='Hora', value=np.arange(len(data_pred_rf_107)))
data_pred_rf_107.set_index('Hora',inplace=True)


(data_pred_rf_107
 .style
 .background_gradient(subset=['media'], cmap='Greens')
 #.highlight_min(axis=0, color='white')
 #.highlight_max(axis=0, color='red')
 .set_caption('Predicciones 24H Paseo Alameda'))
# Out:
# <style  type="text/css" >
# #T_fc12d_row0_col0{
#             background-color:  #daf0d4;
#             color:  #000000;
#         }#T_fc12d_row1_col0{
#             background-color:  #e3f4de;
#             color:  #000000;
#         }#T_fc12d_row2_col0{
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }#T_fc12d_row3_col0,#T_fc12d_row4_col0,#T_fc12d_row5_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_fc12d_row6_col0{
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }#T_fc12d_row7_col0{
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }#T_fc12d_row8_col0{
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }#T_fc12d_row9_col0{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_fc12d_row10_col0{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_fc12d_row11_col0{
#             background-color:  #329b51;
#             color:  #000000;
#         }#T_fc12d_row12_col0{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_fc12d_row13_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_fc12d_row14_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_fc12d_row15_col0{
#             background-color:  #005f26;
#             color:  #f1f1f1;
#         }#T_fc12d_row16_col0{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_fc12d_row17_col0,#T_fc12d_row18_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_fc12d_row19_col0{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_fc12d_row20_col0{
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }#T_fc12d_row21_col0{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_fc12d_row22_col0{
#             background-color:  #92d28f;
#             color:  #000000;
#         }#T_fc12d_row23_col0{
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }</style><table id="T_fc12d_" ><caption>Predicciones 24H Paseo Alameda</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >media</th>    </tr>    <tr>        <th class="index_name level0" >Hora</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc12d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fc12d_row0_col0" class="data row0 col0" >486.257325</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fc12d_row1_col0" class="data row1 col0" >443.688294</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fc12d_row2_col0" class="data row2 col0" >320.477692</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fc12d_row3_col0" class="data row3 col0" >297.806959</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fc12d_row4_col0" class="data row4 col0" >297.806959</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fc12d_row5_col0" class="data row5 col0" >294.372533</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fc12d_row6_col0" class="data row6 col0" >347.501496</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fc12d_row7_col0" class="data row7 col0" >653.403219</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fc12d_row8_col0" class="data row8 col0" >1195.186187</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fc12d_row9_col0" class="data row9 col0" >1185.241371</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_fc12d_row10_col0" class="data row10 col0" >1142.616665</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_fc12d_row11_col0" class="data row11 col0" >1052.023492</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_fc12d_row12_col0" class="data row12 col0" >1144.641114</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_fc12d_row13_col0" class="data row13 col0" >1261.784478</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_fc12d_row14_col0" class="data row14 col0" >1257.411398</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_fc12d_row15_col0" class="data row15 col0" >1311.043773</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_fc12d_row16_col0" class="data row16 col0" >1319.849892</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_fc12d_row17_col0" class="data row17 col0" >1402.672490</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_fc12d_row18_col0" class="data row18 col0" >1398.782752</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_fc12d_row19_col0" class="data row19 col0" >1338.417857</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_fc12d_row20_col0" class="data row20 col0" >1329.637744</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_fc12d_row21_col0" class="data row21 col0" >1314.757921</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_fc12d_row22_col0" class="data row22 col0" >754.413860</td>
#             </tr>
#             <tr>
#                         <th id="T_fc12d_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_fc12d_row23_col0" class="data row23 col0" >450.805607</td>
#             </tr>
#     </tbody></table>

# %%
media_RF_24_107 = data_pred_rf_107.mean()
print(media_RF_24_107)

max_RF_24_107 = data_pred_rf_107.max()
print(max_RF_24_107)

min_RF_24_107 = data_pred_rf_107.min()
print(min_RF_24_107)
# Out:
# media    916.691712
# dtype: float64
# media    1402.67249
# dtype: float64
# media    294.372533
# dtype: float64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 5))
sns.lineplot(data=data_pred_rf_107).set(title='Predicciones 24 Horas Paseo Alameda')
# Out:
# [Text(0.5, 1.0, 'Predicciones 24 Horas Paseo Alameda')]

# %%
#Medias tramo 107 31/12/2015
df_before_107 = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 12) & \
                                     (dataML_tramos['dia'] == 31) & (dataML_tramos['id_tramos'] == 107)]
df_before_107
# Out:
#           año  mes  dia  horas  dias_sem  id_tramos  festivo        media
# 3001814  2015   12   31      1         4        107        0   328.750000
# 3002216  2015   12   31      2         4        107        0   257.000000
# 3002617  2015   12   31      4         4        107        0    86.000000
# 3003018  2015   12   31      5         4        107        0    99.000000
# 3003391  2015   12   31      8         4        107        0   577.333333
# 3003791  2015   12   31      9         4        107        0   637.000000
# 3004188  2015   12   31     10         4        107        0   910.250000
# 3004582  2015   12   31     11         4        107        0  1172.250000
# 3004972  2015   12   31     12         4        107        0  1336.500000
# 3005347  2015   12   31     13         4        107        0  1497.250000
# 3005717  2015   12   31     15         4        107        0  1267.750000
# 3006106  2015   12   31     16         4        107        0   961.333333
# 3006505  2015   12   31     17         4        107        0   979.250000
# 3006903  2015   12   31     18         4        107        0   953.000000
# 3007298  2015   12   31     22         4        107        0   387.666667
# 3007700  2015   12   31     23         4        107        0   218.000000

# %%
new_row_0 = [2015, 12, 31,0,4,1082,0,412.250000]
new_row_1 = [2015, 12, 31,3,4,1082,0,131.000000]
new_row_2 = [2015, 12, 31,6,4,1082,0,184.500000]
new_row_3 = [2015, 12, 31,7,4,1082,0,378.750000]
new_row_4 = [2015, 12, 31,14,4,1082,0,1647.000000]
new_row_5 = [2015, 12, 31,19,4,1082,0,912.000000]
new_row_6 = [2015, 12, 31,20,4,1082,0,763.750000]
new_row_7 = [2015, 12, 31,21,4,1082,0,501.000000]


df_before_107.loc[len(df_before_107.index)] = new_row_0
df_before_107.loc[len(df_before_107.index)] = new_row_1
df_before_107.loc[len(df_before_107.index)] = new_row_2
df_before_107.loc[len(df_before_107.index)] = new_row_3
df_before_107.loc[len(df_before_107.index)] = new_row_4
df_before_107.loc[len(df_before_107.index)] = new_row_5
df_before_107.loc[len(df_before_107.index)] = new_row_6
df_before_107.loc[len(df_before_107.index)] = new_row_7

df_sorted_107= df_before_107.sort_values('horas')
df_sorted_107_mean = df_sorted_107['media'].tolist()
df_sorted_107_mean
# Out:
# [412.25,
#  328.75,
#  257.0,
#  131.0,
#  86.0,
#  99.0,
#  184.5,
#  378.75,
#  577.3333333333334,
#  637.0,
#  910.25,
#  1172.25,
#  1336.5,
#  1497.25,
#  1647.0,
#  1267.75,
#  961.3333333333334,
#  979.25,
#  953.0,
#  912.0,
#  763.75,
#  501.0,
#  387.6666666666667,
#  218.0]

# %%
df_dates_107 = dates_24.copy()
df_dates_107['Media'] = df_sorted_107_mean
df_dates_107.set_index('Fecha',inplace=True)
df_dates_107
# Out:
#                            Media
# Fecha
# 2015-12-31 00:00:00   412.250000
# 2015-12-31 01:00:00   328.750000
# 2015-12-31 02:00:00   257.000000
# 2015-12-31 03:00:00   131.000000
# 2015-12-31 04:00:00    86.000000
# 2015-12-31 05:00:00    99.000000
# 2015-12-31 06:00:00   184.500000
# 2015-12-31 07:00:00   378.750000
# 2015-12-31 08:00:00   577.333333
# 2015-12-31 09:00:00   637.000000
# 2015-12-31 10:00:00   910.250000
# 2015-12-31 11:00:00  1172.250000
# 2015-12-31 12:00:00  1336.500000
# 2015-12-31 13:00:00  1497.250000
# 2015-12-31 14:00:00  1647.000000
# 2015-12-31 15:00:00  1267.750000
# 2015-12-31 16:00:00   961.333333
# 2015-12-31 17:00:00   979.250000
# 2015-12-31 18:00:00   953.000000
# 2015-12-31 19:00:00   912.000000
# 2015-12-31 20:00:00   763.750000
# 2015-12-31 21:00:00   501.000000
# 2015-12-31 22:00:00   387.666667
# 2015-12-31 23:00:00   218.000000

# %%
df_pred_dates_107 = pred_dates_24.copy()
df_pred_dates_107['Media'] = new_predictions_107
df_pred_dates_107.set_index('Fecha',inplace=True)
df_pred_dates_107
# Out:
#                            Media
# Fecha
# 2016-01-01 00:00:00   486.257325
# 2016-01-01 01:00:00   443.688294
# 2016-01-01 02:00:00   320.477692
# 2016-01-01 03:00:00   297.806959
# 2016-01-01 04:00:00   297.806959
# 2016-01-01 05:00:00   294.372533
# 2016-01-01 06:00:00   347.501496
# 2016-01-01 07:00:00   653.403219
# 2016-01-01 08:00:00  1195.186187
# 2016-01-01 09:00:00  1185.241371
# 2016-01-01 10:00:00  1142.616665
# 2016-01-01 11:00:00  1052.023492
# 2016-01-01 12:00:00  1144.641114
# 2016-01-01 13:00:00  1261.784478
# 2016-01-01 14:00:00  1257.411398
# 2016-01-01 15:00:00  1311.043773
# 2016-01-01 16:00:00  1319.849892
# 2016-01-01 17:00:00  1402.672490
# 2016-01-01 18:00:00  1398.782752
# 2016-01-01 19:00:00  1338.417857
# 2016-01-01 20:00:00  1329.637744
# 2016-01-01 21:00:00  1314.757921
# 2016-01-01 22:00:00   754.413860
# 2016-01-01 23:00:00   450.805607

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_dates_107, linestyle='solid', color='b')
plt.plot(df_pred_dates_107, linestyle='solid', color='r')

plt.legend(['2015','pred_107'], loc='best', prop={'size': 10})
plt.title('Evolución Predicciones Tramo 107 24 Horas', weight='bold', fontsize=12)
plt.ylabel('Media Tráfico', weight='bold', fontsize=10)
plt.xlabel('Fecha', weight='bold', fontsize=10)
plt.xticks(weight='bold', fontsize=10, rotation=45)
plt.yticks(weight='bold', fontsize=10)
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------**
# **-------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ***Gráficos Predicciones 24 Horas***

# %%
fig, axes = plt.subplots(2, 3, figsize=(14, 8),sharey=True)
#plt.margins(x=0,y=0)

fig.suptitle('Predicciones Tramos 24 Horas',fontsize=15)

#sns.lineplot(ax=axes[0, 0], data=df_before_101['media'],color='red',label='dataset').set_title('Tramo 101')
sns.lineplot(ax=axes[0, 0], data=data_pred_rf_101['media'],color='blue',label='pred_101')
sns.lineplot(ax=axes[0, 1], data=data_pred_rf_1027['media'],color='blue',label='pred_1027')
sns.lineplot(ax=axes[0, 2], data=data_pred_rf_1069['media'],color='blue',label='pred_1069')
sns.lineplot(ax=axes[1, 0], data=data_pred_rf_1082['media'],color='blue',label='pred_1082')
sns.lineplot(ax=axes[1, 1], data=data_pred_rf_10357['media'],color='blue',label='pred_10357')
sns.lineplot(ax=axes[1, 2], data=data_pred_rf_107['media'],color='blue',label='pred_107')
# Out:
# <AxesSubplot:xlabel='Hora', ylabel='media'>

# %% [markdown]
# ***Gráficos Evolución Predicciones***

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8),sharey=True)
plt.margins(x=0,y=0)
fig.tight_layout(pad=6.0)
fig.suptitle('Predicciones Tramos 24 Horas',fontsize=15, weight='bold')

sns.lineplot(ax=axes[0, 0], data=df_dates_101['Media'],color='blue',label='31/12').set_title('Acceso V-21')
sns.lineplot(ax=axes[0, 0], data=df_pred_dates_101['Media'],color='red',label='01/01').set_title('Acceso V-21')
axes[0][0].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[0, 1], data=df_dates_1027['Media'],color='blue',label='31/12').set_title('Av. Ausias March')
sns.lineplot(ax=axes[0, 1], data=df_pred_dates_1027['Media'],color='red',label='01/01').set_title('Av. Ausias March')
axes[0][1].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[0, 2], data=df_dates_1069['Media'],color='blue',label='31/12').set_title('Av. del Cid')
sns.lineplot(ax=axes[0, 2], data=df_pred_dates_1069['Media'],color='red',label='01/01').set_title('Av. del Cid')
axes[0][2].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 0], data=df_dates_1082['Media'],color='blue',label='31/12').set_title('Av. Cortes Valencianas')
sns.lineplot(ax=axes[1, 0], data=df_pred_dates_1082['Media'],color='red',label='01/01').set_title('Av. Cortes Valencianas')
axes[1][0].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 1], data=df_dates_10357['Media'],color='blue',label='31/12').set_title('Plaza Ayuntamiento')
sns.lineplot(ax=axes[1, 1], data=df_pred_dates_10357['Media'],color='red',label='01/01').set_title('Plaza Ayuntamiento')
axes[1][1].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 2], data=df_dates_107['Media'],color='blue',label='31/12').set_title('Paseo Alameda')
sns.lineplot(ax=axes[1, 2], data=df_pred_dates_107['Media'],color='red',label='01/01').set_title('Paseo Alameda')
axes[1][2].tick_params(axis='x', rotation=45)

# %%
#https://www.geeksforgeeks.org/dummy-regressor/
#https://www.kaggle.com/satishgunjal/tutorial-k-fold-cross-validation
#https://www.datasciencesmachinelearning.com/2018/12/time-series-cross-validation-and.html
#https://towardsdatascience.com/multiple-time-series-forecasting-with-pycaret-bc0a779a22fe
#https://www.aprendemachinelearning.com/sets-de-entrenamiento-test-validacion-cruzada/
#https://www.simplilearn.com/tutorials/machine-learning-tutorial/cross-validation
#https://algotrading101.com/learn/train-test-split/
#https://www.ritchieng.com/machine-learning-cross-validation/

# %% [markdown]
# ***Medias 24 Horas Tramos 01/01/2015***

# %% [markdown]
# 101

# %%
#Medias tramo 101 01/01/2015
df_101_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 101)]

df_101_previous = df_101_year_ago[['horas','media']]
df_101_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_101_previous.set_index('Hora',inplace=True)
df_101_previous.head(5)
# Out:
#             media
# Hora
# 0      419.333333
# 1     1524.666667
# 2     1118.666667
# 3      776.000000
# 4      652.666667

# %% [markdown]
# 1027

# %%
#Medias tramo 1027 01/01/2015
df_1027_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 1027)]
df_1027_previous = df_1027_year_ago[['horas','media']]
df_1027_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_1027_previous.set_index('Hora',inplace=True)
df_1027_previous.head(5)
# Out:
#             media
# Hora
# 0      422.333333
# 1     1415.333333
# 2     1154.000000
# 3      863.000000
# 4      765.000000

# %% [markdown]
# 1069

# %%
#Medias tramo 1069 01/01/2015
df_1069_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 1069)]
df_1069_previous = df_1069_year_ago[['horas','media']]
df_1069_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_1069_previous.set_index('Hora',inplace=True)
df_1069_previous.head(5)
# Out:
#             media
# Hora
# 0      530.000000
# 1     1487.333333
# 2     1227.000000
# 3      773.666667
# 4      843.333333

# %% [markdown]
# 1082

# %%
#Medias tramo 1082 01/01/2015
df_1082_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 1082)]
df_1082_previous = df_1082_year_ago[['horas','media']]
df_1082_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_1082_previous.set_index('Hora',inplace=True)
df_1082_previous.head(5)
# Out:
#             media
# Hora
# 0      794.666667
# 1     2736.000000
# 2     2182.666667
# 3     1540.000000
# 4     1343.000000

# %% [markdown]
# 10357

# %%
#Medias tramo 101 01/01/2015
df_10357_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 10357)]

df_10357_previous = df_10357_year_ago[['horas','media']]
df_10357_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_10357_previous.set_index('Hora',inplace=True)
df_10357_previous.head(5)
# Out:
#             media
# Hora
# 0      539.666667
# 1     2712.666667
# 2     1918.333333
# 3     1338.000000
# 4     1042.666667

# %%
#Medias tramo 101 01/01/2015
df_107_year_ago = dataML_tramos.loc[(dataML_tramos['año'] == 2015) & (dataML_tramos['mes'] == 1) & \
                                     (dataML_tramos['dia'] == 1) & (dataML_tramos['id_tramos'] == 107)]

df_107_previous = df_107_year_ago[['horas','media']]
df_107_previous.rename(columns={'horas':'Hora'}, inplace=True)
df_107_previous.set_index('Hora',inplace=True)
df_107_previous.head(5)
# Out:
#             media
# Hora
# 0      370.000000
# 1     1165.666667
# 2     1083.000000
# 3      811.333333
# 4      683.666667

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8),sharey=True)
plt.margins(x=0,y=0)
fig.tight_layout(pad=6.0)
fig.suptitle('Comparación Tráfico 01/01/2015 con Predicciones 01/01/2016 24H',fontsize=15, weight='bold')

sns.lineplot(ax=axes[0, 0], data=df_101_previous['media'],color='blue',label='2015').set_title('Acceso V-21')
sns.lineplot(ax=axes[0, 0], data=data_pred_rf_101['media'],color='red',label='2016').set_title('Acceso V-21')
axes[0][0].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[0, 1], data=df_1027_previous['media'],color='blue',label='2015').set_title('Av. Ausias March')
sns.lineplot(ax=axes[0, 1], data=data_pred_rf_1027['media'],color='red',label='2016').set_title('Av. Ausias March')
axes[0][1].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[0, 2], data=df_1069_previous['media'],color='blue',label='2015').set_title('Av. del Cid')
sns.lineplot(ax=axes[0, 2], data=data_pred_rf_1069['media'],color='red',label='2016').set_title('Av. del Cid')
axes[0][2].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 0], data=df_1082_previous['media'],color='blue',label='2015').set_title('Av. Cortes Valencianas')
sns.lineplot(ax=axes[1, 0], data=data_pred_rf_1082['media'],color='red',label='2016').set_title('Av. Cortes Valencianas')
axes[1][0].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 1], data=df_10357_previous['media'],color='blue',label='2015').set_title('Plaza Ayuntamiento')
sns.lineplot(ax=axes[1, 1], data=data_pred_rf_10357['media'],color='red',label='2016').set_title('Plaza Ayuntamiento')
axes[1][1].tick_params(axis='x', rotation=45)

sns.lineplot(ax=axes[1, 2], data=df_107_previous['media'],color='blue',label='2015').set_title('Paseo Alameda')
sns.lineplot(ax=axes[1, 2], data=data_pred_rf_107['media'],color='red',label='2016').set_title('Paseo Alameda')
axes[1][2].tick_params(axis='x', rotation=45)
